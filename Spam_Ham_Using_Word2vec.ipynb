# %%
# !pip install gensim
# Out:
# Requirement already satisfied: gensim in c:\users\rkroh\anaconda3\lib\site-packages (4.4.0)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\rkroh\anaconda3\lib\site-packages (from gensim) (2.3.5)
# Requirement already satisfied: scipy>=1.7.0 in c:\users\rkroh\anaconda3\lib\site-packages (from gensim) (1.16.3)
# Requirement already satisfied: smart_open>=1.8.1 in c:\users\rkroh\anaconda3\lib\site-packages (from gensim) (7.6.0)
# Requirement already satisfied: wrapt in c:\users\rkroh\anaconda3\lib\site-packages (from smart_open>=1.8.1->gensim) (1.17.0)

# %%
import gensim 
from gensim.models import Word2Vec, KeyedVectors

# %%
import pandas as pd
messages = pd.read_csv("SpamClassifier-master\smsspamcollection\SMSSpamCollection", sep = "\t", names = ["label", "message"])

# %%
messages.shape
# Out:
# (5572, 2)

# %%
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

# %%
import re
import nltk
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\rkroh\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
corpus = []
for i in range(0, len(messages)):
    review = re.sub("^a-zA-z", " ", messages["message"][i])
    review = review.lower()
    review = review.split()

    review = [lemmatizer.lemmatize(word) for word in review]
    review = " ".join(review)
    corpus.append(review)

# %%
corpus
# Out:
# ['go until jurong point, crazy.. available only in bugis n great world la e buffet... cine there got amore wat...',
#  'ok lar... joking wif u oni...',
#  "free entry in 2 a wkly comp to win fa cup final tkts 21st may 2005. text fa to 87121 to receive entry question(std txt rate)t&c's apply 08452810075over18's",
#  'u dun say so early hor... u c already then say...',
#  "nah i don't think he go to usf, he life around here though",
#  "freemsg hey there darling it's been 3 week's now and no word back! i'd like some fun you up for it still? tb ok! xxx std chgs to send, £1.50 to rcv",
#  'even my brother is not like to speak with me. they treat me like aid patent.',
#  "a per your request 'melle melle (oru minnaminunginte nurungu vettam)' ha been set a your callertune for all callers. press *9 to copy your friend callertune",
#  'winner!! a a valued network customer you have been selected to receivea £900 prize reward! to claim call 09061701461. claim code kl341. valid 12 hour only.',
#  'had your mobile 11 month or more? u r entitled to update to the latest colour mobile with camera for free! call the mobile update co free on 08002986030',
#  "i'm gonna be home soon and i don't want to talk about this stuff anymore tonight, k? i've cried enough today.",
#  'six chance to win cash! from 100 to 20,000 pound txt> csh11 and send to 87575. cost 150p/day, 6days, 16+ tsandcs apply reply hl 4 info',
#  'urgent! you have won a 1 week free membership in our £100,000 prize jackpot! txt the word: claim to no: 81010 t&c www.dbuk.net lccltd pobox 4403ldnw1a7rw18',
#  "i've been searching for the right word to thank you for this breather. i promise i wont take your help for granted and will fulfil my promise. you have been wonderful and a blessing at all times.",
#  'i have a date on sunday with will!!',
#  'xxxmobilemovieclub: to use your credit, click the wap link in the next txt message or click here>> http://wap.xxxmobilemovieclub.com?n=qjkgighjjgcbl',
#  "oh k...i'm watching here:)",
#  'eh u remember how 2 spell his name... yes i did. he v naughty make until i v wet.',
#  'fine if that\x92s the way u feel. that\x92s the way it gota b',
#  'england v macedonia - dont miss the goals/team news. txt ur national team to 87077 eg england to 87077 try:wales, scotland 4txt/ú1.20 poboxox36504w45wq 16+',
#  'is that seriously how you spell his name?',
#  'i‘m going to try for 2 month ha ha only joking',
#  'so ü pay first lar... then when is da stock comin...',
#  'aft i finish my lunch then i go str down lor. ard 3 smth lor. u finish ur lunch already?',
#  'ffffffffff. alright no way i can meet up with you sooner?',
#  "just forced myself to eat a slice. i'm really not hungry tho. this sucks. mark is getting worried. he know i'm sick when i turn down pizza. lol",
#  'lol your always so convincing.',
#  "did you catch the bus ? are you frying an egg ? did you make a tea? are you eating your mom's left over dinner ? do you feel my love ?",
#  "i'm back &amp; we're packing the car now, i'll let you know if there's room",
#  'ahhh. work. i vaguely remember that! what doe it feel like? lol',
#  "wait that's still not all that clear, were you not sure about me being sarcastic or that that's why x doesn't want to live with u",
#  "yeah he got in at 2 and wa v apologetic. n had fallen out and she wa actin like spoilt child and he got caught up in that. till 2! but we won't go there! not doing too badly cheers. you?",
#  'k tell me anything about you.',
#  'for fear of fainting with the of all that housework you just did? quick have a cuppa',
#  'thanks for your subscription to ringtone uk your mobile will be charged £5/month please confirm by replying yes or no. if you reply no you will not be charged',
#  'yup... ok i go home look at the timing then i msg ü again... xuhui going to learn on 2nd may too but her lesson is at 8am',
#  "oops, i'll let you know when my roommate's done",
#  'i see the letter b on my car',
#  'anything lor... u decide...',
#  "hello! how's you and how did saturday go? i wa just texting to see if you'd decided to do anything tomo. not that i'm trying to invite myself or anything!",
#  'pls go ahead with watts. i just wanted to be sure. do have a great weekend. abiola',
#  'did i forget to tell you ? i want you , i need you, i crave you ... but most of all ... i love you my sweet arabian steed ... mmmmmm ... yummy',
#  '07732584351 - rodger burn - msg = we tried to call you re your reply to our sm for a free nokia mobile + free camcorder. please call now 08000930705 for delivery tomorrow',
#  'who are you seeing?',
#  'great! i hope you like your man well endowed. i am &lt;#&gt; inches...',
#  'no calls..messages..missed call',
#  "didn't you get hep b immunisation in nigeria.",
#  'fair enough, anything going on?',
#  "yeah hopefully, if tyler can't do it i could maybe ask around a bit",
#  "u don't know how stubborn i am. i didn't even want to go to the hospital. i kept telling mark i'm not a weak sucker. hospital are for weak suckers.",
#  'what you thinked about me. first time you saw me in class.',
#  'a gram usually run like &lt;#&gt; , a half eighth is smarter though and get you almost a whole second gram for &lt;#&gt;',
#  "k fyi x ha a ride early tomorrow morning but he's crashing at our place tonight",
#  'wow. i never realized that you were so embarassed by your accomodations. i thought you liked it, since i wa doing the best i could and you always seemed so happy about "the cave". i\'m sorry i didn\'t and don\'t have more to give. i\'m sorry i offered. i\'m sorry your room wa so embarassing.',
#  'sms. ac sptv: the new jersey devil and the detroit red wing play ice hockey. correct or incorrect? end? reply end sptv',
#  'do you know what mallika sherawat did yesterday? find out now @ &lt;url&gt;',
#  'congrats! 1 year special cinema pas for 2 is yours. call 09061209465 now! c suprman v, matrix3, starwars3, etc all 4 free! bx420-ip4-5we. 150pm. dont miss out!',
#  "sorry, i'll call later in meeting.",
#  'tell where you reached',
#  'yes..gauti and sehwag out of odi series.',
#  "your gonna have to pick up a $1 burger for yourself on your way home. i can't even move. pain is killing me.",
#  'ha ha ha good joke. girl are situation seekers.',
#  'it a part of checking iq',
#  'sorry my roommate took forever, it ok if i come by now?',
#  'ok lar i double check wif da hair dresser already he said wun cut v short. he said will cut until i look nice.',
#  'a a valued customer, i am pleased to advise you that following recent review of your mob no. you are awarded with a £1500 bonus prize, call 09066364589',
#  'today is "song dedicated day.." which song will u dedicate for me? send this to all ur valuable frnds but first rply me...',
#  'urgent ur awarded a complimentary trip to eurodisinc trav, aco&entry41 or £1000. to claim txt dis to 87121 18+6*£1.50(morefrmmob. shracomorsglsuplt)10, ls1 3aj',
#  'did you hear about the new "divorce barbie"? it come with all of ken\'s stuff!',
#  'i plane to give on this month end.',
#  'wah lucky man... then can save money... hee...',
#  'finished class where are you.',
#  'hi babe im at home now wanna do something? xx',
#  'k..k:)where are you?how did you performed?',
#  'u can call me now...',
#  'i am waiting machan. call me once you free.',
#  'thats cool. i am a gentleman and will treat you with dignity and respect.',
#  'i like you people very much:) but am very shy pa.',
#  'doe not operate after &lt;#&gt; or what',
#  "it not the same here. still looking for a job. how much do ta's earn there.",
#  "sorry, i'll call later",
#  'k. did you call me just now ah?',
#  'ok i am on the way to home hi hi',
#  'you will be in the place of that man',
#  'yup next stop.',
#  "i call you later, don't have network. if urgnt, sm me.",
#  "for real when u getting on yo? i only need 2 more ticket and one more jacket and i'm done. i already used all my multis.",
#  "yes i started to send request to make it but pain came back so i'm back in bed. double coin at the factory too. i gotta cash in all my nitros.",
#  "i'm really not up to it still tonight babe",
#  'ela kano.,il download, come wen ur free..',
#  'yeah do! don‘t stand to close tho- you‘ll catch something!',
#  "sorry to be a pain. is it ok if we meet another night? i spent late afternoon in casualty and that mean i haven't done any of y stuff42moro and that includes all my time sheet and that. sorry.",
#  'smile in pleasure smile in pain smile when trouble pours like rain smile when sum1 hurt u smile becoz someone still love to see u smiling!!',
#  'please call our customer service representative on 0800 169 6031 between 10am-9pm a you have won a guaranteed £1000 cash or £5000 prize!',
#  'havent planning to buy later. i check already lido only got 530 show in e afternoon. u finish work already?',
#  'your free ringtone is waiting to be collected. simply text the password "mix" to 85069 to verify. get usher and britney. fml, po box 5249, mk17 92h. 450ppw 16',
#  'watching telugu movie..wat abt u?',
#  'i see. when we finish we have load of loan to pay',
#  'hi. wk been ok - on hols now! yes on for a bit of a run. forgot that i have hairdresser appointment at four so need to get home n shower beforehand. doe that cause prob for u?"',
#  'i see a cup of coffee animation',
#  "please don't text me anymore. i have nothing else to say.",
#  'okay name ur price a long a it legal! wen can i pick them up? y u ave x am xx',
#  "i'm still looking for a car to buy. and have not gone 4the driving test yet.",
#  "a per your request 'melle melle (oru minnaminunginte nurungu vettam)' ha been set a your callertune for all callers. press *9 to copy your friend callertune",
#  "wow. you're right! i didn't mean to do that. i guess once i gave up on boston men and changed my search location to nyc, something changed. cuz on my signin page it still say boston.",
#  'umma my life and vava umma love you lot dear',
#  'thanks a lot for your wish on my birthday. thanks you for making my birthday truly memorable.',
#  "aight, i'll hit you up when i get some cash",
#  "how would my ip address test that considering my computer isn't a minecraft server",
#  'i know! grumpy old people. my mom wa like you better not be lying. then again i am always the one to play jokes...',
#  "dont worry. i guess he's busy.",
#  'what is the plural of the noun research?',
#  'going for dinner.msg you after.',
#  "i'm ok wif it co i like 2 try new things. but i scared u dun like mah. co u said not too loud.",
#  'gent! we are trying to contact you. last weekend draw show that you won a £1000 prize guaranteed. call 09064012160. claim code k52. valid 12hrs only. 150ppm',
#  "wa, ur openin sentence very formal... anyway, i'm fine too, juz tt i'm eatin too much n puttin on weight...haha... so anythin special happened?",
#  "a i entered my cabin my pa said, '' happy b'day bos !!''. i felt special. she askd me 4 lunch. after lunch she invited me to her apartment. we went there.",
#  'you are a winner u have been specially selected 2 receive £1000 or a 4* holiday (flights inc) speak to a live operator 2 claim 0871277810910p/min (18+)',
#  'goodo! yes we must speak friday - egg-potato ratio for tortilla needed!',
#  "hmm...my uncle just informed me that he's paying the school directly. so pls buy food.",
#  'private! your 2004 account statement for 07742676969 show 786 unredeemed bonus points. to claim call 08719180248 identifier code: 45239 expires',
#  'urgent! your mobile no. wa awarded £2000 bonus caller prize on 5/9/03 this is our final try to contact u! call from landline 09064019788 box42wr29c, 150ppm',
#  'here is my new address -apples&pairs&all that malarky',
#  'today voda number ending 7548 are selected to receive a $350 award. if you have a match please call 08712300220 quoting claim code 4041 standard rate app',
#  'i am going to sao mu today. will be done only at 12',
#  "ü predict wat time ü'll finish buying?",
#  'good stuff, will do.',
#  "just so that you know,yetunde hasn't sent money yet. i just sent her a text not to bother sending. so it over, you dont have to involve yourself in anything. i shouldn't have imposed anything on you in the first place so for that, i apologise.",
#  'are you there in room.',
#  'hey girl. how r u? hope u r well me an del r bak! again long time no c! give me a call sum time from lucyxx',
#  'k..k:)how much doe it cost?',
#  "i'm home.",
#  'dear, will call tmorrow.pls accomodate.',
#  'first answer my question.',
#  'sunshine quiz wkly q! win a top sony dvd player if u know which country the algarve is in? txt ansr to 82277. £1.50 sp:tyrone',
#  "want 2 get laid tonight? want real dogging location sent direct 2 ur mob? join the uk's largest dogging network bt txting gravel to 69888! nt. ec2a. 31p.msg@150p",
#  "i only haf msn. it's yijue@hotmail.com",
#  'he is there. you call and meet him',
#  'no no. i will check all room befor activity',
#  "you'll not rcv any more msg from the chat svc. for free hardcore service text go to: 69988 if u get nothing u must age verify with yr network & try again",
#  'got c... i lazy to type... i forgot ü in lect... i saw a pouch but like not v nice...',
#  "k, text me when you're on the way",
#  'sir, waiting for your mail.',
#  'a swt thought: "nver get tired of doing little thing 4 lovable persons.." coz..somtimes those little thing occupy d biggest part in their hearts.. gud ni8',
#  'i know you are. can you pls open the back?',
#  'yes see ya not on the dot',
#  'whats the staff name who is taking class for us?',
#  "freemsg why haven't you replied to my text? i'm randy, sexy, female and live local. luv to hear from u. netcollex ltd 08700621170150p per msg reply stop to end",
#  'ummma.will call after check in.our life will begin from qatar so pls pray very hard.',
#  'k..i deleted my contact that why?',
#  'sindu got job in birla soft ..',
#  "the wine is flowing and i'm i have nevering..",
#  'yup i thk cine is better co no need 2 go down 2 plaza mah.',
#  'ok... ur typical reply...',
#  "a per your request 'melle melle (oru minnaminunginte nurungu vettam)' ha been set a your callertune for all callers. press *9 to copy your friend callertune",
#  'you are everywhere dirt, on the floor, the windows, even on my shirt. and sometimes when i open my mouth, you are all that come flowing out. i dream of my world without you, then half my chore are out too. a time of joy for me, lot of tv show i.ll see. but i guess like all thing you just must exist, like rain, hail and mist, and when my time here is done, you and i become one.',
#  'aaooooright are you at work?',
#  "i'm leaving my house now...",
#  'hello, my love. what are you doing? did you get to that interview today? are you you happy? are you being a good boy? do you think of me?are you missing me ?',
#  'customer service annoncement. you have a new year delivery waiting for you. please call 07046744435 now to arrange delivery',
#  'you are a winner u have been specially selected 2 receive £1000 cash or a 4* holiday (flights inc) speak to a live operator 2 claim 0871277810810',
#  "keep yourself safe for me because i need you and i miss you already and i envy everyone that see's you in real life",
#  'new car and house for my parents.:)i have only new job in hand:)',
#  "i'm so in love with you. i'm excited each day i spend with you. you make me so happy.",
#  '-pls stop bootydelious (32/f) is inviting you to be her friend. reply yes-434 or no-434 see her: www.sms.ac/u/bootydelious stop? send stop frnd to 62468',
#  'bangbabes ur order is on the way. u should receive a service msg 2 download ur content. if u do not, goto wap. bangb. tv on ur mobile internet/service menu',
#  'i place all ur point on e culture module already.',
#  'urgent! we are trying to contact you. last weekend draw show that you have won a £900 prize guaranteed. call 09061701939. claim code s89. valid 12hrs only',
#  "hi frnd, which is best way to avoid missunderstding wit our beloved one's?",
#  'great escape. i fancy the bridge but need her lager. see you tomo',
#  'yes :)it completely in out of form:)clark also utter waste.',
#  'sir, i need axis bank account no and bank address.',
#  'hmmm.. thk sure got time to hop ard... ya, can go 4 free abt... muz call u to discus liao...',
#  'what time you coming down later?',
#  'bloody hell, cant believe you forgot my surname mr . ill give u a clue, it spanish and begin with m...',
#  "well, i'm gonna finish my bath now. have a good...fine night.",
#  "let me know when you've got the money so carlos can make the call",
#  'u still going to the mall?',
#  "turn out my friend are staying for the whole show and won't be back til ~ &lt;#&gt; , so feel free to go ahead and smoke that $ &lt;#&gt; worth",
#  'text her. if she doesnt reply let me know so i can have her log in',
#  "hi! you just spoke to maneesha v. we'd like to know if you were satisfied with the experience. reply toll free with yes or no.",
#  'you lifted my hope with the offer of money. i am in need. especially when the end of the month approach and it hurt my studying. anyways have a gr8 weekend',
#  'lol no. u can trust me.',
#  'ok. i am a gentleman and will treat you with dignity and respect.',
#  'he will, you guy close?',
#  'going on nothing great.bye',
#  "hello handsome ! are you finding that job ? not being lazy ? working towards getting back that net for mummy ? where's my boytoy now ? doe he miss me ?",
#  'haha awesome, be there in a minute',
#  'please call our customer service representative on freephone 0808 145 4742 between 9am-11pm a you have won a guaranteed £1000 cash or £5000 prize!',
#  'have you got xmas radio times. if not i will get it now',
#  'i jus reached home. i go bathe first. but my si using net tell u when she finish k...',
#  'are you unique enough? find out from 30th august. www.areyouunique.co.uk',
#  "i'm sorry. i've joined the league of people that dont keep in touch. you mean a great deal to me. you have been a friend at all time even at great personal cost. do have a great week.|",
#  'hi :)finally i completed the course:)',
#  'it will stop on itself. i however suggest she stay with someone that will be able to give or for every stool.',
#  "how are you doing? hope you've settled in for the new school year. just wishin you a gr8 day",
#  'gud mrng dear hav a nice day',
#  'did u got that person story',
#  'is your hamster dead? hey so tmr i meet you at 1pm orchard mrt?',
#  'hi it kate how is your evening? i hope i can see you tomorrow for a bit but i have to bloody babyjontet! txt back if u can. :) xxx',
#  'found it, enc &lt;#&gt; , where you at?',
#  'i sent you &lt;#&gt; buck',
#  'hello darlin ive finished college now so txt me when u finish if u can love kate xxx',
#  'your account ha been refilled successfully by inr &lt;decimal&gt; . your keralacircle prepaid account balance is r &lt;decimal&gt; . your transaction id is kr &lt;#&gt; .',
#  'goodmorning sleeping ga.',
#  'u call me alter at 11 ok.',
#  'ü say until like dat i dun buy ericsson oso cannot oredi lar...',
#  "a i entered my cabin my pa said, '' happy b'day bos !!''. i felt special. she askd me 4 lunch. after lunch she invited me to her apartment. we went there.",
#  'aight yo, dat straight dogg',
#  'you please give u connection today itself before &lt;decimal&gt; or refund the bill',
#  'both :) i shoot big load so get ready!',
#  "what's up bruv, hope you had a great break. do have a rewarding semester.",
#  'home so we can always chat',
#  'k:)k:)good:)study well.',
#  'yup... how ü noe leh...',
#  'sound great! are you home now?',
#  'finally the match heading towards draw a your prediction.',
#  "tired. i haven't slept well the past few nights.",
#  'easy ah?sen got selected mean it good..',
#  'i have to take exam with march 3',
#  "yeah you should. i think you can use your gt atm now to register. not sure but if there's anyway i can help let me know. but when you do be sure you are ready.",
#  'ok no prob. take ur time.',
#  'there is o called ubandu which will run without installing in hard disk...you can use that o to copy the important file in system and give it to repair shop..',
#  "sorry, i'll call later",
#  'u say leh... of course nothing happen lar. not say v romantic jus a bit only lor. i thk e nite scenery not so nice leh.',
#  '500 new mobile from 2004, must go! txt: nokia to no: 89545 & collect yours today!from only £1 www.4-tc.biz 2optout 087187262701.50gbp/mtmsg18',
#  'would really appreciate if you call me. just need someone to talk to.',
#  'will u meet ur dream partner soon? is ur career off 2 a flyng start? 2 find out free, txt horo followed by ur star sign, e. g. horo aries',
#  'hey company elama po mudyadhu.',
#  'life is more strict than teacher... bcoz teacher teach lesson &amp; then conduct exam, but life first conduct exam &amp; then teach lessons. happy morning. . .',
#  'dear good morning now only i am up',
#  'get down in gandhipuram and walk to cross cut road. right side &lt;#&gt; street road and turn at first right.',
#  'dear we are going to our rubber place',
#  "sorry battery died, yeah i'm here",
#  'yes:)here tv is always available in work place..',
#  'text & meet someone sexy today. u can find a date or even flirt it up to u. join 4 just 10p. reply with name & age eg sam 25. 18 -msg recd@thirtyeight penny',
#  'i have printed it oh. so &lt;#&gt; come upstairs',
#  'or ill be a little closer like at the bus stop on the same street',
#  'where are you?when wil you reach here?',
#  "new theory: argument win d situation, but loses the person. so dont argue with ur friend just.. . . . kick them &amp; say, i'm always correct.!",
#  'u 447801259231 have a secret admirer who is looking 2 make contact with u-find out who they r*reveal who think ur so special-call on 09058094597',
#  'tomarrow final hearing on my laptop case so i cant.',
#  'pleassssssseeeeee tel me v avent done sportsx',
#  'okay. no no, just shining on. that wa meant to be signing, but that sound better.',
#  "although i told u dat i'm into baig face watch now but i really like e watch u gave co it's fr u. thanx 4 everything dat u've done today, i'm touched...",
#  "u don't remember that old commercial?",
#  "too late. i said i have the website. i didn't i have or dont have the slipper",
#  'i asked you to call him now ok',
#  'kallis wont bat in 2nd innings.',
#  'it didnt work again oh. ok goodnight then. i.ll fix and have it ready by the time you wake up. you are very dearly missed have a good night sleep.',
#  'congratulation ur awarded 500 of cd voucher or 125gift guaranteed & free entry 2 100 wkly draw txt music to 87066 tncs www.ldew.com1win150ppmx3age16',
#  'ranjith cal drpd deeraj and deepak 5min hold',
#  'wen ur lovable bcums angry wid u, dnt take it seriously.. coz being angry is d most childish n true way of showing deep affection, care n luv!.. kettoda manda... have nice day da.',
#  'what you doing?how are you?',
#  'ups which is 3days also, and the shipping company that take 2wks. the other way is usps which take a week but when it get to lag you may have to bribe nipost to get your stuff.',
#  "i'm back, lemme know when you're ready",
#  "don't necessarily expect it to be done before you get back though because i'm just now headin out",
#  'mmm so yummy babe ... nice jolt to the suzy',
#  'where are you lover ? i need you ...',
#  'we tried to contact you re your reply to our offer of a video handset? 750 anytime network mins? unlimited text? camcorder? reply or call 08000930705 now',
#  'i‘m parked next to a mini!!!! when are you coming in today do you think?',
#  'yup',
#  "anyway i'm going shopping on my own now. co my si not done yet. dun disturb u liao.",
#  'my no. in luton 0125698789 ring me if ur around! h*',
#  'hey i am really horny want to chat or see me naked text hot to 69698 text charged at 150pm to unsubscribe text stop 69698',
#  'why you dint come with us.',
#  'same. wana plan a trip sometme then',
#  'not sure yet, still trying to get a hold of him',
#  'ur ringtone service ha changed! 25 free credits! go to club4mobiles.com to choose content now! stop? txt club stop to 87070. 150p/wk club4 po box1146 mk45 2wt',
#  'the evo. i just had to download flash. jealous?',
#  'ringtone club: get the uk single chart on your mobile each week and choose any top quality ringtone! this message is free of charge.',
#  "come to mu, we're sorting out our narcotic situation",
#  'night ha ended for another day, morning ha come in a special way. may you smile like the sunny ray and leaf your worry at the blue blue bay.',
#  'hmv bonus special 500 pound of genuine hmv voucher to be won. just answer 4 easy questions. play now! send hmv to 86688 more info:www.100percent-real.com',
#  'usf i guess, might a well take 1 car',
#  'no objection. my bf not coming.',
#  'thanx...',
#  'tell rob to mack his gf in the theater',
#  "awesome, i'll see you in a bit",
#  'just sent it. so what type of food do you like?',
#  'all done? all handed in? celebration in full swing yet?',
#  'you got called a tool?',
#  'wen u miss someone, the person is definitely special for u..... but if the person is so special, why to miss them, just keep-in-touch gdeve..',
#  'ok. i asked for money how far',
#  'okie...',
#  "yeah i think my usual guy's still passed out from last night, if you get ahold of anybody let me know and i'll throw down",
#  'k, i might come by tonight then if my class let out early',
#  'ok..',
#  'hi baby im cruisin with my girl friend what r u up 2? give me a call in and hour at home if thats alright or fone me on this fone now love jenny xxx',
#  'my life mean a lot to me, not because i love my life, but because i love the people in my life, the world call them friends, i call them my world:-).. ge:-)..',
#  'dear,shall mail tonite.busy in the street,shall update you tonite.things are looking ok.varunnathu edukkukayee raksha ollu.but a good one in real sense.',
#  'hey you told your name to gautham ah?',
#  'haf u found him? i feel so stupid da v cam wa working.',
#  'oops. 4 got that bit.',
#  'are you this much buzy',
#  'i accidentally deleted the message. resend please.',
#  "t-mobile customer you may now claim your free camera phone upgrade & a pay & go sim card for your loyalty. call on 0845 021 3680.offer end 28thfeb.t&c's apply",
#  "unless it's a situation where you go gurl would be more appropriate",
#  'hurt me... tease me... make me cry... but in the end of my life when i die plz keep one rose on my grave and say stupid i miss u.. have a nice day bslvyl',
#  'i cant pick the phone right now. pls send a message',
#  "need a coffee run tomo?can't believe it's that time of week already",
#  'awesome, i remember the last time we got somebody high for the first time with diesel :v',
#  'shit that is really shocking and scary, cant imagine for a second. def up for night out. do u think there is somewhere i could crash for night, save on taxi?',
#  'oh and by the way you do have more food in your fridge! want to go out for a meal tonight?',
#  'he is a womdarfull actor',
#  'sms. ac blind date 4u!: rodds1 is 21/m from aberdeen, united kingdom. check him out http://img. sms. ac/w/icmb3cktz8r7!-4 no blind date send hide',
#  'yup... from what i remb... i think should be can book...',
#  'jos ask if u wana meet up?',
#  "lol yes. our friendship is hanging on a thread cause u won't buy stuff.",
#  'themob> check out our newest selection of content, games, tones, gossip, babe and sport, keep your mobile fit and funky text wap to 82468',
#  "where are the garage keys? they aren't on the bookshelf",
#  'today is accept day..u accept me as? brother sister lover dear1 best1 clos1 lvblefrnd jstfrnd cutefrnd lifpartnr belovd swtheart bstfrnd no rply mean enemy',
#  'think ur smart ? win £200 this week in our weekly quiz, text play to 85222 now!t&cs winnersclub po box 84, m26 3uz. 16+. gbp1.50/week',
#  "he say he'll give me a call when his friend's got the money but that he's definitely buying before the end of the week",
#  'hi the way i wa with u 2day, is the normal way&this is the real me. ur unique&i hope i know u 4 the rest of mylife. hope u find wot wa lost.',
#  'you made my day. do have a great day too.',
#  'k.k:)advance happy pongal.',
#  'hmmm... guess we can go 4 kb n power yoga... haha, dunno we can tahan power yoga anot... thk got lo oso, forgot liao...',
#  "not really dude, have no friend i'm afraid :(",
#  'december only! had your mobile 11mths+? you are entitled to update to the latest colour camera mobile for free! call the mobile update co free on 08002986906',
#  'coffee cake, i guess...',
#  'merry christmas to you too babe, i love ya *kisses*',
#  'hey... why dont we just go watch x men and have lunch... haha',
#  'cud u tell ppl im gona b a bit l8 co 2 bus hav gon past co they were full & im still waitin 4 1. pete x',
#  "that would be great. we'll be at the guild. could meet on bristol road or somewhere - will get in touch over weekend. our plan take flight! have a good week",
#  'no problem. how are you doing?',
#  'no calls..messages..missed call',
#  'hi da:)how is the today class?',
#  "i'd say that's a good sign but, well, you know my track record at reading woman",
#  "cool, text me when you're parked",
#  "i'm reading the text i just sent you. it meant to be a joke. so read it in that light",
#  'k.k:)apo k.good movie.',
#  'maybe i could get book out tomo then return it immediately ..? or something.',
#  'call germany for only 1 penny per minute! call from a fixed line via access number 0844 861 85 85. no prepayment. direct access!',
#  "any chance you might have had with me evaporated a soon a you violated my privacy by stealing my phone number from your employer's paperwork. not cool at all. please do not contact me again or i will report you to your supervisor.",
#  'valentine day special! win over £1000 in our quiz and take your partner on the trip of a lifetime! send go to 83600 now. 150p/msg rcvd. custcare:08718720201.',
#  'ta-daaaaa! i am home babe, are you still up ?',
#  'cool. so how come you havent been wined and dined before?',
#  'just sleeping..and surfing',
#  "sorry, i'll call later",
#  'u calling me right? call my hand phone...',
#  "ok that's great thanx a lot.",
#  'i take it the post ha come then! you must have 1000 of text now! happy reading. my one from wiv hello caroline at the end is my favourite. bless him',
#  'where u been hiding stranger?',
#  'am not interested to do like that.',
#  'my sister cleared two round in birla soft yesterday.',
#  'gudnite....tc...practice going on',
#  'dis is yijue. i jus saw ur mail. in case huiming havent sent u my num. dis is my num.',
#  'one small prestige problem now.',
#  'fancy a shag? i do.interested? sextextuk.com txt xxuk suzy to 69876. txts cost 1.50 per msg. tncs on website. x',
#  'just checking in on you. really do miss seeing jeremiah. do have a great month',
#  "nah can't help you there, i've never had an iphone",
#  "if you're not in my car in an hour and a half i'm going apeshit",
#  "today is sorry day.! if ever i wa angry with you, if ever i misbehaved or hurt you? plz plz just slap urself bcoz, it ur fault, i'm basically good",
#  'yo you guy ever figure out how much we need for alcohol? jay and i are trying to figure out how much we can safely spend on weed',
#  '&lt;#&gt; ish minute wa 5 minute ago. wtf.',
#  'thank you for calling.forgot to say happy onam to you sirji.i am fine here and remembered you when i met an insurance person.meet you in qatar insha allah.rakhesh, ex tata aig who joined tissco,tayseer.',
#  'congratulation ur awarded 500 of cd voucher or 125gift guaranteed & free entry 2 100 wkly draw txt music to 87066 tncs www.ldew.com1win150ppmx3age16',
#  'ur cash-balance is currently 500 pound - to maximize ur cash-in now send cash to 86688 only 150p/msg. cc: 08708800282 hg/suite342/2lands row/w1j6hl',
#  "i'm an actor. when i work, i work in the evening and sleep late. since i'm unemployed at the moment, i always sleep late. when you're unemployed, every day is saturday.",
#  'hello! just got here, st andrews-boy it a long way! it cold. i will keep you posted',
#  'ha ha cool cool chikku chikku:-):-db-)',
#  'oh ok no prob..',
#  "check audrey's status right now",
#  'busy here. trying to finish for new year. i am looking forward to finally meeting you...',
#  'good afternoon sunshine! how dawn that day ? are we refreshed and happy to be alive? do we breathe in the air and smile ? i think of you, my love ... a always',
#  'well i know z will take care of me. so no worries.',
#  'update_now - xmas offer! latest motorola, sonyericsson & nokia & free bluetooth! double min & 1000 txt on orange. call mobileupd8 on 08000839402 or call2optout/f4q=',
#  'here is your discount code rp176781. to stop further message reply stop. www.regalportfolio.co.uk. customer service 08717205546',
#  'wat uniform? in where get?',
#  "cool, text me when you're ready",
#  'hello my boytoy ... geeee i miss you already and i just woke up. i wish you were here in bed with me, cuddling me. i love you ...',
#  'i will spoil you in bed a well :)',
#  "i'm going for bath will msg you next &lt;#&gt; min..",
#  'i cant keep talking to people if am not sure i can pay them if they agree to price. so pls tell me what you want to really buy and how much you are willing to pay',
#  'thanks for your ringtone order, reference t91. you will be charged gbp 4 per week. you can unsubscribe at anytime by calling customer service on 09057039994',
#  'can you say what happen',
#  "you could have seen me..i did't recognise you face.:)",
#  "well there's not a lot of thing happening in lindsay on new year *sighs* some bar in ptbo and the blue heron ha something going",
#  'keep my payasam there if rinu brings',
#  'i taught that ranjith sir called me. so only i sm like that. becaus he verifying about project. prabu told today so only pa dont mistake me..',
#  "i guess that's why you re worried. you must know that there's a way the body repair itself. and i'm quite sure you shouldn't worry. we'll take it slow. first the tests, they will guide when your ovulation is then just relax. nothing you've said is a reason to worry but i.ll keep on followin you up.",
#  'yeah sure, give me a couple minute to track down my wallet',
#  'hey leave it. not a big deal:-) take care.',
#  'hey i will be late ah... meet you at 945+',
#  'double min and txts 4 6months free bluetooth on orange. available on sony, nokia motorola phones. call mobileupd8 on 08000839402 or call2optout/n9dx',
#  'it took mr owl 3 lick',
#  'customer place i will call you.',
#  'mm that time you dont like fun',
#  '4mths half price orange line rental & latest camera phone 4 free. had your phone 11mths ? call mobilesdirect free on 08000938767 to update now! or2stoptxt',
#  'yup having my lunch buffet now.. u eat already?',
#  'huh so late... fr dinner?',
#  'hey so this sat are we going for the intro pilate only? or the kickboxing too?',
#  'morning only i can ok.',
#  'yes i think so. i am in office but my lap is in room i think thats on for the last few days. i didnt shut that down',
#  'pick you up bout 7.30ish? what time are and that going?',
#  'from here after the performance award is calculated every two month.not for current one month period..',
#  'wa actually sleeping and still might when u call back. so a text is gr8. you rock sis. will send u a text wen i wake.',
#  "you are always putting your business out there. you put picture of your as on facebook. you are one of the most open people i've ever met. why would i think a picture of your room would hurt you, make you feel violated.",
#  'good evening sir, al salam wahleykkum.sharing a happy news.by the grace of god, i got an offer from tayseer,tissco and i joined.hope you are fine.inshah allah,meet you sometime.rakhesh,visitor from india.',
#  'hmmm...k...but i want to change the field quickly da:-)i wanna get system administrator or network administrator..',
#  'free ringtone text first to 87131 for a poly or text get to 87131 for a true tone! help? 0845 2814032 16 after 1st free, tone are 3x£150pw to e£nd txt stop',
#  'dear how is chechi. did you talk to her',
#  'the hair cream ha not been shipped.',
#  "none of that's happening til you get here though",
#  'yep, the great loxahatchee xmas tree burning of &lt;#&gt; start in an hour',
#  'haha get used to driving to usf man, i know a lot of stoner',
#  "all wa well until slightly disastrous class this pm with my fav darlings! hope day off ok. coffee wld be good a can't stay late tomorrow. same time + place a always?",
#  'hello! good week? fancy a drink or something later?',
#  'headin towards busetop',
#  'message:some text missing* sender:name missing* *number missing *sent:date missing *missing u a lot thats y everything is missing sent via fullonsms.com',
#  'come by our room at some point so we can iron out the plan for this weekend',
#  'co i want it to be your thing',
#  "okies... i'll go yan jiu too... we can skip ard oso, go cine den go mrt one, blah blah blah...",
#  'bring home some wendy =d',
#  '100 dating service cal;l 09064012103 box334sk38ch',
#  'whatsup there. dont u want to sleep',
#  'alright i have a new goal now',
#  'free entry into our £250 weekly competition just text the word win to 80086 now. 18 t&c www.txttowin.co.uk',
#  "alright, i'll head out in a few minutes, text me where to meet you",
#  'send a logo 2 ur lover - 2 name joined by a heart. txt love name1 name2 mobno eg love adam eve 07123456789 to 87077 yahoo! pobox36504w45wq txtno 4 no ad 150p',
#  "yes:)from last week itself i'm taking live call.",
#  'someone ha contacted our dating service and entered your phone because they fancy you! to find out who it is call from a landline 09111032124 . pobox12n146tf150p',
#  'siva is in hostel aha:-.',
#  'urgent! your mobile number ha been awarded with a £2000 prize guaranteed. call 09058094455 from land line. claim 3030. valid 12hrs only',
#  'send this to ur friend and receive something about ur voice..... how is my speaking expression? 1.childish 2.naughty 3.sentiment 4.rowdy 5.ful of attitude 6.romantic 7.shy 8.attractive 9.funny &lt;#&gt; .irritating &lt;#&gt; .lovable. reply me..',
#  "ok. she'll be ok. i guess",
#  'aathi..where are you dear..',
#  'any pain on urination any thing else?',
#  '7 at esplanade.. do ü mind giving me a lift co i got no car today..',
#  'i wnt to buy a bmw car urgently..its vry urgent.but hv a shortage of &lt;#&gt; lacs.there is no source to arng dis amt. &lt;#&gt; lacs..thats my prob',
#  'at home watching tv lor.',
#  'doe she usually take fifteen fucking minute to respond to a yes or no question',
#  'congrats! nokia 3650 video camera phone is your call 09066382422 call cost 150ppm ave call 3mins vary from mobile 16+ close 300603 post bcm4284 ldn wc1n3xx',
#  'booked ticket for pongal?',
#  "you available now? i'm like right around hillsborough &amp; &lt;#&gt; th",
#  'the message sent is askin for &lt;#&gt; dollars. shoul i pay &lt;#&gt; or &lt;#&gt; ?',
#  "ask g or iouri, i've told the story like ten time already",
#  'how long doe applebees fucking take',
#  'hi hope u get this txt~journey hasnt been gd,now about 50 min late i think.',
#  'but i have to. i like to have love and arrange.',
#  'yes..he is really great..bhaji told kallis best cricketer after sachin in world:).very tough to get out.',
#  'you were supposed to wake me up &gt;:(',
#  'oic... i saw him too but i tot he din c me... i found a group liao...',
#  "sorry, i'll call later",
#  'hey hey werethe monkeespeople say we monkeyaround! howdy gorgeous, howu doin? foundurself a jobyet sausage?love jen xxx',
#  "sorry, my battery died, i can come by but i'm only getting a gram for now, where's your place?",
#  'well done, blimey, exercise, yeah, i kinda remember wot that is, hmm.',
#  'i wont get concentration dear you know you are my mind and everything :-)',
#  'lol ... have you made plan for new years?',
#  '10 min later k...',
#  'hank lotsly!',
#  'thanks for this hope you had a good day today',
#  'k:)k:)what are detail you want to transfer?acc no enough?',
#  'ok i will tell her to stay out. yeah it been tough but we are optimistic thing will improve this month.',
#  "loan for any purpose £500 - £75,000. homeowner + tenant welcome. have you been previously refused? we can still help. call free 0800 1956669 or text back 'help'",
#  'si si. i think ill go make those oreo truffles.',
#  'look at amy ure a beautiful, intelligent woman and i like u a lot. i know u don\x92t like me like that so don\x92t worry.',
#  "i hope you that's the result of being consistently intelligent and kind. start asking him about practicum link and keep your ear open and all the best. ttyl",
#  '1.20 that call cost. which i guess isnt bad. miss ya, need ya, want ya, love ya',
#  'going thru a very different feeling.wavering decision and coping up with the same is the same individual.time will heal everything i believe.',
#  'where did u go? my phone is gonna die you have to stay in here',
#  'great. never been better. each day give even more reason to thank god',
#  "upgrdcentre orange customer, you may now claim your free camera phone upgrade for your loyalty. call now on 0207 153 9153. offer end 26th july. t&c's apply. opt-out available",
#  "sorry, i'll call later ok bye",
#  'ok i am on the way to railway',
#  'great princess! i love giving and receiving oral. doggy style is my fave position. how about you? i enjoy making love &lt;#&gt; time per night :)',
#  "they don't put that stuff on the road to keep it from getting slippery over there?",
#  'when are you going to ride your bike?',
#  "yup, no need. i'll jus wait 4 e rain 2 stop.",
#  'there are many company. tell me the language.',
#  'okmail: dear dave this is your final notice to collect your 4* tenerife holiday or #5000 cash award! call 09061743806 from landline. tc sae box326 cw25wx 150ppm',
#  'how long ha it been since you screamed, princess?',
#  'nothing. i meant that once the money enters your account here, the bank will remove it flat rate. someone transfered &lt;#&gt; to my account and &lt;#&gt; dollar got removed. so the bank differ and charge also differ.be sure you trust the 9ja person you are sending account detail to cos...',
#  "want 2 get laid tonight? want real dogging location sent direct 2 ur mob? join the uk's largest dogging network by txting moan to 69888nyt. ec2a. 31p.msg@150p",
#  "nice line said by a broken heart- plz don't cum 1 more time infront of me... other wise once again i ll trust u... good 9t:)",
#  "ok i'm gonna head up to usf in like fifteen minute",
#  'love you aathi..love u lot..',
#  'tension ah?what machi?any problem?',
#  "k, can i pick up another 8th when you're done?",
#  "when're you guy getting back? g said you were thinking about not staying for mcr",
#  'almost there, see u in a sec',
#  'yo carlos, a few friend are already asking me about you, you working at all this weekend?',
#  'watching tv lor...',
#  'thank you baby! i cant wait to taste the real thing...',
#  'you should change your fb to jaykwon thuglyfe falconerf',
#  'if we win it really no 1 side for long time.',
#  'free message activate your 500 free text message by replying to this message with the word free for term & conditions, visit www.07781482378.com',
#  'dear reached railway. what happen to you',
#  'depends on quality. if you want the type i sent boye, faded glory, then about 6. if you want ralphs maybe 2',
#  "i think i've fixed it can you send a test message?",
#  "sorry man my account's dry or i would, if you want we could trade back half or i could buy some shit with my credit card",
#  'congrats! 1 year special cinema pas for 2 is yours. call 09061209465 now! c suprman v, matrix3, starwars3, etc all 4 free! bx420-ip4-5we. 150pm. dont miss out!',
#  "sorry,in meeting i'll call later",
#  'what class of &lt;#&gt; reunion?',
#  'are you free now?can i call now?',
#  'got meh... when?',
#  'nope... think i will go for it on monday... sorry i replied so late',
#  'some of them told accenture is not confirm. is it true.',
#  'kate jackson rec center before 7ish, right?',
#  'dear i have reache room',
#  'fighting with the world is easy, u either win or lose bt fightng with some1 who is close to u is dificult if u lose - u lose if u win - u still lose.',
#  'when can ü come out?',
#  'check with nuerologist.',
#  'lolnice. i went from a fish to ..water.?',
#  "+123 congratulation - in this week's competition draw u have won the £1450 prize to claim just call 09050002311 b4280703. t&cs/stop sm 08718727868. over 18 only 150ppm",
#  "no it's waiting in e car dat's bored wat. co wait outside got nothing 2 do. at home can do my stuff or watch tv wat.",
#  'maybe westshore or hyde park village, the place near my house?',
#  "you should know now. so how's anthony. are you bringing money. i've school fee to pay and rent and stuff like that. thats why i need your help. a friend in need....|",
#  "what's the significance?",
#  'your opinion about me? 1. over 2. jada 3. kusruthi 4. lovable 5. silent 6. spl character 7. not matured 8. stylish 9. simple pls reply..',
#  "8 at the latest, g's still there if you can scrounge up some ammo and want to give the new ak a try",
#  "prabha..i'm soryda..realy..frm heart i'm sory",
#  'lol ok your forgiven :)',
#  'no..jst change tat only..',
#  'you are guaranteed the latest nokia phone, a 40gb ipod mp3 player or a £500 prize! txt word: collect to no: 83355! ibhltd ldnw15h 150p/mtmsgrcvd18+',
#  's:)no competition for him.',
#  'boltblue tone for 150p reply poly# or mono# eg poly3 1. cha cha slide 2. yeah 3. slow jamz 6. toxic 8. come with me or stop 4 more tone txt more',
#  'your credit have been topped up for http://www.bubbletext.com your renewal pin is tgxxrz',
#  'that way transport is less problematic than on sat night. by the way, if u want to ask n to join my bday, feel free. but need to know definite no a booking on fri.',
#  "usually the person is unconscious that's in child but in adult they may just behave abnormally. i.ll call you now",
#  "but that's on ebay it might be less elsewhere.",
#  'shall i come to get pickle',
#  'were gonna go get some taco',
#  "that's very rude, you on campus?",
#  'urgent!: your mobile no. wa awarded a £2,000 bonus caller prize on 02/09/03! this is our 2nd attempt to contact you! call 0871-872-9755 box95qu',
#  "hi i won't b ard 4 christmas. but do enjoy n merry x'mas.",
#  "today's offer! claim ur £150 worth of discount vouchers! text yes to 85023 now! savamob, member offer mobile! t c 08717898035. £3.00 sub. 16 . unsub reply x",
#  'yes! how is a pretty lady like you single?',
#  'you will recieve your tone within the next 24hrs. for term and condition please see channel u teletext pg 750',
#  "jay say that you're a double-faggot",
#  'private! your 2003 account statement for 07815296484 show 800 un-redeemed s.i.m. points. call 08718738001 identifier code 41782 expires 18/11/04',
#  'what today-sunday..sunday is holiday..so no work..',
#  'gudnite....tc...practice going on',
#  "i'll be late...",
#  "i've not called you in a while. this is hoping it wa l8r malaria and that you know that we miss you guys. i miss ban big, so pls give her my love especially. have a great day.",
#  'good afternoon, my love! how go that day ? i hope maybe you got some lead on a job. i think of you, boytoy and send you a passionate kiss from across the sea',
#  'probably gonna be here for a while, see you later tonight &lt;)',
#  "or maybe my fat finger just press all these button and it doesn't know what to do.",
#  'ummmmmaah many many happy return of d day my dear sweet heart.. happy birthday dear',
#  'i am in tirupur da, once you started from office call me.',
#  'from www.applausestore.com monthlysubscription@50p/msg max6/month t&csc web age16 2stop txt stop',
#  "a famous quote : when you develop the ability to listen to 'anything' unconditionally without losing your temper or self confidence, it mean you are ......... 'married'",
#  'but am going to college pa. what to do. are else ill come there it self. pa.',
#  '4 oclock at mine. just to bash out a flat plan.',
#  "this girl doe not stay in bed. this girl doesn't need recovery time. id rather pas out while having fun then be cooped up in bed",
#  'then any special there?',
#  "i know but you need to get hotel now. i just got my invitation but i had to apologise. cali is to sweet for me to come to some english bloke's weddin",
#  'sorry that took so long, omw now',
#  'wait &lt;#&gt; min..',
#  "ok give me 5 minute i think i see her. btw you're my alibi. you were cutting my hair the whole time.",
# ...
#  'u have a secret admirer. reveal who think u r so special. call 09065174042. to opt out reply reveal stop. 1.50 per msg recd. cust care 07821230901',
#  'hi mate it rv did u hav a nice hol just a message 3 say hello coz haven\x92t sent u 1 in age started driving so stay off roads!rvx',
#  'dear voucher holder, to claim this week offer, at you pc please go to http://www.e-tlp.co.uk/expressoffer ts&cs apply. to stop texts, txt stop to 80062',
#  "thank you so much. when we skyped wit kz and sura, we didnt get the pleasure of your company. hope you are good. we've given you ultimatum oh! we are countin down to aburo. enjoy! this is the message i sent day ago",
#  'surely result will offer:)',
#  'good morning my dear........... have a great &amp; successful day.',
#  'do you want 750 anytime any network min 150 text and a new video phone for only five pound per week call 08002888812 or reply for delivery tomorrow',
#  "sir, i have been late in paying rent for the past few month and had to pay a $ &lt;#&gt; charge. i felt it would be inconsiderate of me to nag about something you give at great cost to yourself and that's why i didnt speak up. i however am in a recession and wont be able to pay the charge this month hence my askin well ahead of month's end. can you please help. thanks",
#  'we tried to contact you re our offer of new video phone 750 anytime any network min half price rental camcorder call 08000930705 or reply for delivery wed',
#  'last chance 2 claim ur £150 worth of discount vouchers-text yes to 85023 now!savamob-member offer mobile t c 08717898035. £3.00 sub. 16 . remove txt x or stop',
#  'i luv u soo much u don\x92t understand how special u r 2 me ring u 2morrow luv u xxx',
#  "pls send me a comprehensive mail about who i'm paying, when and how much.",
#  "our prashanthettan's mother passed away last night. pray for her and family.",
#  'urgent! call 09066350750 from your landline. your complimentary 4* ibiza holiday or 10,000 cash await collection sae t&cs po box 434 sk3 8wp 150 ppm 18+',
#  'k.k:)when are you going?',
#  "meanwhile in the shit suite: xavier decided to give u &lt;#&gt; second of warning that samantha wa coming over and is playing jay's guitar to impress her or some shit. also i don't think doug realizes i don't live here anymore",
#  "my stomach ha been thru so much trauma i swear i just can't eat. i better lose weight.",
#  'i am in office:)whats the matter..msg me now.i will call you at break:).',
#  "yeah there's barely enough room for the two of us, x ha too many fucking shoes. sorry man, see you later",
#  "today's offer! claim ur £150 worth of discount vouchers! text yes to 85023 now! savamob, member offer mobile! t c 08717898035. £3.00 sub. 16 . unsub reply x",
#  'u reach orchard already? u wan 2 go buy ticket first?',
#  'i am real, baby! i want to bring out your inner tigress...',
#  'no da if you run that it activate the full version da.',
#  'ah poor baby!hope urfeeling bettersn luv! probthat overdose of work hey go careful spk 2 u sn lot of lovejen xxx.',
#  "stop the story. i've told him i've returned it and he's saying i should not re order it.",
#  'talk sexy!! make new friend or fall in love in the world most discreet text dating service. just text vip to 83110 and see who you could meet.',
#  'going to take your babe out ?',
#  'hai ana tomarrow am coming on morning. &lt;decimal&gt; ill be there in sathy then we ll go to rto office. reply me after came to home.',
#  'spoon it is then okay?',
#  'did he just say somebody is named tampa',
#  'in work now. going have in few min.',
#  'your brother is a genius',
#  "sorry, i guess whenever i can get a hold of my connections, maybe an hour or two? i'll text you",
#  'did u find out what time the bus is at coz i need to sort some stuff out.',
#  'dude ive been seeing a lotta corvette lately',
#  'congratulation ur awarded either a yr supply of cd from virgin record or a mystery gift guaranteed call 09061104283 ts&cs www.smsco.net £1.50pm approx 3mins',
#  "same here, but i consider wall and bunker and shit important just because i never play on peaceful but i guess your place is high enough that it don't matter",
#  'private! your 2003 account statement for 07808 xxxxxx show 800 un-redeemed s. i. m. points. call 08719899217 identifier code: 41685 expires 07/11/04',
#  'hello. we need some posh bird and chap to user trial prod for champneys. can i put you down? i need your address and dob asap. ta r',
#  'what do u want for xmas? how about 100 free text message & a new video phone with half price line rental? call free now on 0800 0721072 to find out more!',
#  'well am officially in a philosophical hole, so if u wanna call am at home ready to be saved!',
#  'it going good...no problem..but still need little experience to understand american customer voice...',
#  "i'll text you when i drop x off",
#  "ugh it been a long day. i'm exhausted. just want to cuddle up and take a nap",
#  'talk with yourself atleast once in a day...!!! otherwise you will miss your best friend in this world...!!! -shakespeare- shesil &lt;#&gt;',
#  'shop till u drop, is it you, either 10k, 5k, £500 cash or £100 travel voucher, call now, 09064011000. ntt po box cr01327bt fixedline cost 150ppm mobile vary',
#  'are you in castor? you need to see something',
#  'sunshine quiz wkly q! win a top sony dvd player if u know which country liverpool played in mid week? txt ansr to 82277. £1.50 sp:tyrone',
#  'u have a secret admirer who is looking 2 make contact with u-find out who they r*reveal who think ur so special-call on 09058094565',
#  'u have a secret admirer who is looking 2 make contact with u-find out who they r*reveal who think ur so special-call on 09065171142-stopsms-08',
#  'reminder: you have not downloaded the content you have already paid for. goto http://doit. mymoby. tv/ to collect your content.',
#  "see, i knew giving you a break a few time woul lead to you always wanting to miss curfew. i wa gonna gibe you 'til one, but a midnight movie is not gonna get out til after 2. you need to come home. you need to getsleep and, if anything, you need to b studdying ear training.",
#  'i love to give massages. i use lot of baby oil... what is your fave position?',
#  'dude we should go sup again',
#  'yoyyooo u know how to change permission for a drive in mac. my usb flash drive',
#  'gibbs unsold.mike hussey',
#  'i like to talk pa but am not able to. i dont know y.',
#  "y dun cut too short leh. u dun like ah? she failed. she's quite sad.",
#  'you unbelievable faglord',
#  'wife.how she knew the time of murder exactly',
#  'why do you ask princess?',
#  'i am great princess! what are you thinking about me? :)',
#  'nutter. cutter. ctter. cttergg. cttargg. ctargg. ctagg. ie you',
#  "it's ok i noe u're busy but i'm really too bored so i msg u. i oso dunno wat colour she choose 4 me one.",
#  "doesn't g have class early tomorrow and thus shouldn't be trying to smoke at &lt;#&gt;",
#  'superb thought- "be grateful that u dont have everything u want. that mean u still have an opportunity to be happier tomorrow than u are today.":-)',
#  'hope you are having a good week. just checking in',
#  "i'm used to it. i just hope my agent don't drop me since i've only booked a few thing this year. this whole me in boston, them in nyc wa an experiment.",
#  "thursday night? yeah, sure thing, we'll work it out then",
#  'your free ringtone is waiting to be collected. simply text the password "mix" to 85069 to verify. get usher and britney. fml, po box 5249, mk17 92h. 450ppw 16',
#  'probably money worries. thing are coming due and i have several outstanding invoice for work i did two and three month ago.',
#  'how is it possible to teach you. and where.',
#  'i wonder if your phone battery went dead ? i had to tell you, i love you babe',
#  "lovely smell on this bus and it ain't tobacco...",
#  "we're all getting worried over here, derek and taylor have already assumed the worst",
#  "hey what's up charles sorry about the late reply.",
#  'all the lastest from stereophonics, marley, dizzee racal, libertine and the strokes! win nookii game with flirt!! click themob wap bookmark or text wap to 82468',
#  'i.ll give her once i have it. plus she said grinule greet you whenever we speak',
#  'white fudge oreo are in store',
#  'january male sale! hot gay chat now cheaper, call 08709222922. national rate from 1.5p/min cheap to 7.8p/min peak! to stop text call 08712460324 (10p/min)',
#  "my love ! how come it took you so long to leave for zaher's? i got your word on ym and wa happy to see them but wa sad you had left. i miss you",
#  'i am sorry it hurt you.',
#  "can't. i feel nauseous. i'm so pissed. i didn't eat any sweet all week cause today i wa planning to pig out. i wa dieting all week. and now i'm not hungry :/",
#  'ok lor but not too early. me still having project meeting now.',
#  'call me da, i am waiting for your call.',
#  'i could ask carlos if we could get more if anybody else can chip in',
#  'wa actually about to send you a reminder today. have a wonderful weekend',
#  "when people see my msgs, they think iam addicted to msging... they are wrong, bcoz they don\\'t know that iam addicted to my sweet friends..!! bslvyl",
#  'hey you gave them your photo when you registered for driving ah? tmr wanna meet at yck?',
#  'dont talk to him ever ok it my word.',
#  'when u wana see it then',
#  "on ma way to school. can you pls send me ashley's number",
#  'it shall be fine. i have avalarr now. will hollalater',
#  "she went to attend another two round today..but still did't reach home..",
#  'actually i deleted my old website..now i m blogging at magicalsongs.blogspot.com',
#  'k, wait chikku..il send aftr &lt;#&gt; min',
#  "but i'm on a diet. and i ate 1 too many slice of pizza yesterday. ugh i'm always on a diet.",
#  'k:)i will give my kvb acc details:)',
#  'oh all have to come ah?',
#  'money!!! you r a lucky winner ! 2 claim your prize text money 2 88600 over £1million to give away ! ppt150x3+normal text rate box403 w1t1jy',
#  "i'm really sorry i won't b able 2 do this friday.hope u can find an alternative.hope yr term's going ok:-)",
#  'congratulation ore mo owo re wa. enjoy it and i wish you many happy moment to and fro wherever you go',
#  'so do you have samus shoulder yet',
#  "what time you think you'll have it? need to know when i should be near campus",
#  'dear matthew please call 09063440451 from a landline, your complimentary 4*lux tenerife holiday or £1000 cash await collection. ppm150 sae t&cs box334 sk38xh.',
#  'then dun wear jean lor...',
#  'since when, which side, any fever, any vomitin.',
#  'k:)k.are you in college?',
#  'urgent! call 09061749602 from landline. your complimentary 4* tenerife holiday or £10,000 cash await collection sae t&cs box 528 hp20 1yf 150ppm 18+',
#  'better. made up for friday and stuffed myself like a pig yesterday. now i feel bleh. but at least it not writhing pain kind of bleh.',
#  "no we sell it all so we'll have ton if coins. then sell our coin to someone thru paypal. voila! money back in life pockets:)",
#  'theyre doing it to lot of places. only hospital and medical place are safe.',
#  'how about getting in touch with folk waiting for company? just txt back your name and age to opt in! enjoy the community (150p/sms)',
#  "and also i've sorta blown him off a couple time recently so id rather not text him out of the blue looking for weed",
#  'i sent my score to sophas and i had to do secondary application for a few schools. i think if you are thinking of applying, do a research on cost also. contact joke ogunrinde, her school is one me the less expensive one',
#  'i cant wait to see you! how were the photo were useful? :)',
#  'ur cash-balance is currently 500 pound - to maximize ur cash-in now send go to 86688 only 150p/msg. cc: 08718720201 po box 114/14 tcr/w1',
#  'hey i booked the kb on sat already... what other lesson are we going for ah? keep your sat night free we need to meet and confirm our lodging',
#  'chk in ur belovd m dict',
#  'is that what time you want me to come?',
#  "awesome, lemme know whenever you're around",
#  'shb b ok lor... thanx...',
#  'beautiful truth against gravity.. read carefully: "our heart feel light when someone is in it.. but it feel very heavy when someone leaf it.." good night',
#  "also remember to get dobby's bowl from your car",
#  'filthy story and girl waiting for your',
#  "sorry i now then c ur msg... yar lor so poor thing... but only 4 one night... tmr u'll have a brand new room 2 sleep in...",
#  "love isn't a decision, it's a feeling. if we could decide who to love, then, life would be much simpler, but then less magical",
#  'welp apparently he retired',
#  "my sort code is and acc no is . the bank is natwest. can you reply to confirm i've sent this to the right person!",
#  'where @',
#  "u sure u can't take any sick time?",
#  'urgent! we are trying to contact u. today draw show that you have won a £800 prize guaranteed. call 09050001808 from land line. claim m95. valid12hrs only',
#  'watching cartoon, listening music &amp; at eve had to go temple &amp; church.. what about u?',
#  'yo chad which gymnastics class do you wanna take? the site say christian class is full..',
#  'are you this much buzy',
#  'or better still can you catch her and let ask her if she can sell &lt;#&gt; for me.',
#  'i am not sure about night menu. . . i know only about noon menu',
#  'what do u want when i come back?.a beautiful necklace a a token of my heart for you.thats what i will give but only to my wife of my liking.be that and see..no one can give you that.dont call me.i will wait till i come.',
#  'are you willing to go for aptitude class.',
#  'it wont b until 2.15 a trying 2 sort house out, is that ok?',
#  'yar lor he wan 2 go c horse racing today mah, so eat earlier lor. i ate chicken rice. u?',
#  'haha awesome, omw back now then',
#  'yup i thk so until e shop close lor.',
#  'what is your account number?',
#  'eh u send wrongly lar...',
#  'hey no i ad a crap nite wa borin without ya 2 boggy with me u boring biatch! thanx but u wait til nxt time il ave ya',
#  'ok i shall talk to him',
#  'dont hesitate. you know this is the second time she ha had weakness like that. so keep i notebook of what she eat and did the day before or if anything changed the day before so that we can be sure it nothing',
#  'hey you can pay. with salary de. only &lt;#&gt; .',
#  'another month. i need chocolate weed and alcohol.',
#  'if he started searching he will get job in few days.he have great potential and talent.',
#  'reckon need to be in town by eightish to walk from * carpark.',
#  'congrats! 2 mobile 3g videophones r yours. call 09063458130 now! videochat wid your mates, play java games, dload polyph music, noline rentl.',
#  'look at the fuckin time. what the fuck you think is up',
#  'yo guess what i just dropped',
#  "carlos say he'll be at mu in &lt;#&gt; minute",
#  "i'm in office now . i will call you &lt;#&gt; min:)",
#  "geeee ... i miss you already, you know ? your all i can think about. fuck, i can't wait till next year when we will be together ... *loving kiss*",
#  'yun ah.the ubi one say if ü wan call by tomorrow.call 67441233 look for irene.ere only got bus8,22,65,61,66,382. ubi cres,ubi tech park.6ph for 1st 5wkg days.èn',
#  'ugh. gotta drive back to sd from la. my butt is sore.',
#  '26th of july',
#  'hi im having the most relaxing time ever! we have to get up at 7am every day! wa the party good the other night? i get home tomorrow at 5ish.',
#  'up to ü... ü wan come then come lor... but i din c any stripe skirt...',
#  'the xmas story is peace.. the xmas msg is love.. the xmas miracle is jesus.. hav a blessed month ahead &amp; wish u merry xmas...',
#  "i can't, i don't have her number!",
#  "change again... it's e one next to escalator...",
#  "yetunde i'm in class can you not run water on it to make it ok. pls now.",
#  'not a lot ha happened here. feel very quiet. beth is at her aunt and charlie is working lots. just me and helen in at the mo. how have you been?',
#  'then ü wait 4 me at bus stop aft ur lect lar. if i dun c ü then i go get my car then come back n pick ü.',
#  ...]

# %%
from nltk import sent_tokenize
from gensim.utils import simple_preprocess

# %%
words = []
for sent in corpus:
    sent_token = sent_tokenize(sent)
    for sent in sent_token:
        words.append(simple_preprocess(sent))

# %%
words
# Out:
# [['go',
#   'until',
#   'jurong',
#   'point',
#   'crazy',
#   'available',
#   'only',
#   'in',
#   'bugis',
#   'great',
#   'world',
#   'la',
#   'buffet',
#   'cine',
#   'there',
#   'got',
#   'amore',
#   'wat'],
#  ['ok', 'lar', 'joking', 'wif', 'oni'],
#  ['free',
#   'entry',
#   'in',
#   'wkly',
#   'comp',
#   'to',
#   'win',
#   'fa',
#   'cup',
#   'final',
#   'tkts',
#   'st',
#   'may',
#   'text',
#   'fa',
#   'to',
#   'to',
#   'receive',
#   'entry',
#   'question',
#   'std',
#   'txt',
#   'rate',
#   'apply',
#   'over'],
#  ['dun', 'say', 'so', 'early', 'hor', 'already', 'then', 'say'],
#  ['nah',
#   'don',
#   'think',
#   'he',
#   'go',
#   'to',
#   'usf',
#   'he',
#   'life',
#   'around',
#   'here',
#   'though'],
#  ['freemsg',
#   'hey',
#   'there',
#   'darling',
#   'it',
#   'been',
#   'week',
#   'now',
#   'and',
#   'no',
#   'word',
#   'back'],
#  ['like', 'some', 'fun', 'you', 'up', 'for', 'it', 'still'],
#  ['tb', 'ok'],
#  ['xxx', 'std', 'chgs', 'to', 'send', 'to', 'rcv'],
#  ['even', 'my', 'brother', 'is', 'not', 'like', 'to', 'speak', 'with', 'me'],
#  ['they', 'treat', 'me', 'like', 'aid', 'patent'],
#  ['per',
#   'your',
#   'request',
#   'melle',
#   'melle',
#   'oru',
#   'minnaminunginte',
#   'nurungu',
#   'vettam',
#   'ha',
#   'been',
#   'set',
#   'your',
#   'callertune',
#   'for',
#   'all',
#   'callers'],
#  ['press', 'to', 'copy', 'your', 'friend', 'callertune'],
#  ['winner'],
#  ['valued',
#   'network',
#   'customer',
#   'you',
#   'have',
#   'been',
#   'selected',
#   'to',
#   'receivea',
#   'prize',
#   'reward'],
#  ['to', 'claim', 'call', 'claim', 'code', 'kl'],
#  ['valid', 'hour', 'only'],
#  ['had', 'your', 'mobile', 'month', 'or', 'more'],
#  ['entitled',
#   'to',
#   'update',
#   'to',
#   'the',
#   'latest',
#   'colour',
#   'mobile',
#   'with',
#   'camera',
#   'for',
#   'free'],
#  ['call', 'the', 'mobile', 'update', 'co', 'free', 'on'],
#  ['gonna',
#   'be',
#   'home',
#   'soon',
#   'and',
#   'don',
#   'want',
#   'to',
#   'talk',
#   'about',
#   'this',
#   'stuff',
#   'anymore',
#   'tonight'],
#  ['ve', 'cried', 'enough', 'today'],
#  ['six', 'chance', 'to', 'win', 'cash'],
#  ['from',
#   'to',
#   'pound',
#   'txt',
#   'csh',
#   'and',
#   'send',
#   'to',
#   'cost',
#   'day',
#   'days',
#   'tsandcs',
#   'apply',
#   'reply',
#   'hl',
#   'info'],
#  ['urgent'],
#  ['you',
#   'have',
#   'won',
#   'week',
#   'free',
#   'membership',
#   'in',
#   'our',
#   'prize',
#   'jackpot'],
#  ['txt',
#   'the',
#   'word',
#   'claim',
#   'to',
#   'no',
#   'www',
#   'dbuk',
#   'net',
#   'lccltd',
#   'pobox',
#   'ldnw',
#   'rw'],
#  ['ve',
#   'been',
#   'searching',
#   'for',
#   'the',
#   'right',
#   'word',
#   'to',
#   'thank',
#   'you',
#   'for',
#   'this',
#   'breather'],
#  ['promise',
#   'wont',
#   'take',
#   'your',
#   'help',
#   'for',
#   'granted',
#   'and',
#   'will',
#   'fulfil',
#   'my',
#   'promise'],
#  ['you', 'have', 'been', 'wonderful', 'and', 'blessing', 'at', 'all', 'times'],
#  ['have', 'date', 'on', 'sunday', 'with', 'will'],
#  [],
#  ['to',
#   'use',
#   'your',
#   'credit',
#   'click',
#   'the',
#   'wap',
#   'link',
#   'in',
#   'the',
#   'next',
#   'txt',
#   'message',
#   'or',
#   'click',
#   'here',
#   'http',
#   'wap',
#   'com',
#   'qjkgighjjgcbl'],
#  ['oh', 'watching', 'here'],
#  ['eh', 'remember', 'how', 'spell', 'his', 'name', 'yes', 'did'],
#  ['he', 'naughty', 'make', 'until', 'wet'],
#  ['fine', 'if', 'that', 'the', 'way', 'feel'],
#  ['that', 'the', 'way', 'it', 'gota'],
#  ['england', 'macedonia', 'dont', 'miss', 'the', 'goals', 'team', 'news'],
#  ['txt',
#   'ur',
#   'national',
#   'team',
#   'to',
#   'eg',
#   'england',
#   'to',
#   'try',
#   'wales',
#   'scotland',
#   'txt',
#   'poboxox',
#   'wq'],
#  ['is', 'that', 'seriously', 'how', 'you', 'spell', 'his', 'name'],
#  ['going', 'to', 'try', 'for', 'month', 'ha', 'ha', 'only', 'joking'],
#  ['so', 'pay', 'first', 'lar', 'then', 'when', 'is', 'da', 'stock', 'comin'],
#  ['aft', 'finish', 'my', 'lunch', 'then', 'go', 'str', 'down', 'lor'],
#  ['ard', 'smth', 'lor'],
#  ['finish', 'ur', 'lunch', 'already'],
#  ['ffffffffff'],
#  ['alright', 'no', 'way', 'can', 'meet', 'up', 'with', 'you', 'sooner'],
#  ['just', 'forced', 'myself', 'to', 'eat', 'slice'],
#  ['really', 'not', 'hungry', 'tho'],
#  ['this', 'sucks'],
#  ['mark', 'is', 'getting', 'worried'],
#  ['he', 'know', 'sick', 'when', 'turn', 'down', 'pizza'],
#  ['lol'],
#  ['lol', 'your', 'always', 'so', 'convincing'],
#  ['did', 'you', 'catch', 'the', 'bus'],
#  ['are', 'you', 'frying', 'an', 'egg'],
#  ['did', 'you', 'make', 'tea'],
#  ['are', 'you', 'eating', 'your', 'mom', 'left', 'over', 'dinner'],
#  ['do', 'you', 'feel', 'my', 'love'],
#  ['back',
#   'amp',
#   'we',
#   're',
#   'packing',
#   'the',
#   'car',
#   'now',
#   'll',
#   'let',
#   'you',
#   'know',
#   'if',
#   'there',
#   'room'],
#  ['ahhh'],
#  ['work'],
#  ['vaguely', 'remember', 'that'],
#  ['what', 'doe', 'it', 'feel', 'like'],
#  ['lol'],
#  ['wait',
#   'that',
#   'still',
#   'not',
#   'all',
#   'that',
#   'clear',
#   'were',
#   'you',
#   'not',
#   'sure',
#   'about',
#   'me',
#   'being',
#   'sarcastic',
#   'or',
#   'that',
#   'that',
#   'why',
#   'doesn',
#   'want',
#   'to',
#   'live',
#   'with'],
#  ['yeah', 'he', 'got', 'in', 'at', 'and', 'wa', 'apologetic'],
#  ['had',
#   'fallen',
#   'out',
#   'and',
#   'she',
#   'wa',
#   'actin',
#   'like',
#   'spoilt',
#   'child',
#   'and',
#   'he',
#   'got',
#   'caught',
#   'up',
#   'in',
#   'that'],
#  ['till'],
#  ['but', 'we', 'won', 'go', 'there'],
#  ['not', 'doing', 'too', 'badly', 'cheers'],
#  ['you'],
#  ['tell', 'me', 'anything', 'about', 'you'],
#  ['for',
#   'fear',
#   'of',
#   'fainting',
#   'with',
#   'the',
#   'of',
#   'all',
#   'that',
#   'housework',
#   'you',
#   'just',
#   'did'],
#  ['quick', 'have', 'cuppa'],
#  ['thanks',
#   'for',
#   'your',
#   'subscription',
#   'to',
#   'ringtone',
#   'uk',
#   'your',
#   'mobile',
#   'will',
#   'be',
#   'charged',
#   'month',
#   'please',
#   'confirm',
#   'by',
#   'replying',
#   'yes',
#   'or',
#   'no'],
#  ['if', 'you', 'reply', 'no', 'you', 'will', 'not', 'be', 'charged'],
#  ['yup',
#   'ok',
#   'go',
#   'home',
#   'look',
#   'at',
#   'the',
#   'timing',
#   'then',
#   'msg',
#   'again',
#   'xuhui',
#   'going',
#   'to',
#   'learn',
#   'on',
#   'nd',
#   'may',
#   'too',
#   'but',
#   'her',
#   'lesson',
#   'is',
#   'at',
#   'am'],
#  ['oops', 'll', 'let', 'you', 'know', 'when', 'my', 'roommate', 'done'],
#  ['see', 'the', 'letter', 'on', 'my', 'car'],
#  ['anything', 'lor', 'decide'],
#  ['hello'],
#  ['how', 'you', 'and', 'how', 'did', 'saturday', 'go'],
#  ['wa',
#   'just',
#   'texting',
#   'to',
#   'see',
#   'if',
#   'you',
#   'decided',
#   'to',
#   'do',
#   'anything',
#   'tomo'],
#  ['not', 'that', 'trying', 'to', 'invite', 'myself', 'or', 'anything'],
#  ['pls', 'go', 'ahead', 'with', 'watts'],
#  ['just', 'wanted', 'to', 'be', 'sure'],
#  ['do', 'have', 'great', 'weekend'],
#  ['abiola'],
#  ['did', 'forget', 'to', 'tell', 'you'],
#  ['want',
#   'you',
#   'need',
#   'you',
#   'crave',
#   'you',
#   'but',
#   'most',
#   'of',
#   'all',
#   'love',
#   'you',
#   'my',
#   'sweet',
#   'arabian',
#   'steed',
#   'mmmmmm',
#   'yummy'],
#  ['rodger',
#   'burn',
#   'msg',
#   'we',
#   'tried',
#   'to',
#   'call',
#   'you',
#   're',
#   'your',
#   'reply',
#   'to',
#   'our',
#   'sm',
#   'for',
#   'free',
#   'nokia',
#   'mobile',
#   'free',
#   'camcorder'],
#  ['please', 'call', 'now', 'for', 'delivery', 'tomorrow'],
#  ['who', 'are', 'you', 'seeing'],
#  ['great'],
#  ['hope', 'you', 'like', 'your', 'man', 'well', 'endowed'],
#  ['am', 'lt', 'gt', 'inches'],
#  ['no', 'calls', 'messages', 'missed', 'call'],
#  ['didn', 'you', 'get', 'hep', 'immunisation', 'in', 'nigeria'],
#  ['fair', 'enough', 'anything', 'going', 'on'],
#  ['yeah',
#   'hopefully',
#   'if',
#   'tyler',
#   'can',
#   'do',
#   'it',
#   'could',
#   'maybe',
#   'ask',
#   'around',
#   'bit'],
#  ['don', 'know', 'how', 'stubborn', 'am'],
#  ['didn', 'even', 'want', 'to', 'go', 'to', 'the', 'hospital'],
#  ['kept', 'telling', 'mark', 'not', 'weak', 'sucker'],
#  ['hospital', 'are', 'for', 'weak', 'suckers'],
#  ['what', 'you', 'thinked', 'about', 'me'],
#  ['first', 'time', 'you', 'saw', 'me', 'in', 'class'],
#  ['gram',
#   'usually',
#   'run',
#   'like',
#   'lt',
#   'gt',
#   'half',
#   'eighth',
#   'is',
#   'smarter',
#   'though',
#   'and',
#   'get',
#   'you',
#   'almost',
#   'whole',
#   'second',
#   'gram',
#   'for',
#   'lt',
#   'gt'],
#  ['fyi',
#   'ha',
#   'ride',
#   'early',
#   'tomorrow',
#   'morning',
#   'but',
#   'he',
#   'crashing',
#   'at',
#   'our',
#   'place',
#   'tonight'],
#  ['wow'],
#  ['never',
#   'realized',
#   'that',
#   'you',
#   'were',
#   'so',
#   'embarassed',
#   'by',
#   'your',
#   'accomodations'],
#  ['thought',
#   'you',
#   'liked',
#   'it',
#   'since',
#   'wa',
#   'doing',
#   'the',
#   'best',
#   'could',
#   'and',
#   'you',
#   'always',
#   'seemed',
#   'so',
#   'happy',
#   'about',
#   'the',
#   'cave'],
#  ['sorry', 'didn', 'and', 'don', 'have', 'more', 'to', 'give'],
#  ['sorry', 'offered'],
#  ['sorry', 'your', 'room', 'wa', 'so', 'embarassing'],
#  ['sms'],
#  ['ac',
#   'sptv',
#   'the',
#   'new',
#   'jersey',
#   'devil',
#   'and',
#   'the',
#   'detroit',
#   'red',
#   'wing',
#   'play',
#   'ice',
#   'hockey'],
#  ['correct', 'or', 'incorrect'],
#  ['end'],
#  ['reply', 'end', 'sptv'],
#  ['do', 'you', 'know', 'what', 'mallika', 'sherawat', 'did', 'yesterday'],
#  ['find', 'out', 'now', 'lt', 'url', 'gt'],
#  ['congrats'],
#  ['year', 'special', 'cinema', 'pas', 'for', 'is', 'yours'],
#  ['call', 'now'],
#  ['suprman', 'matrix', 'starwars', 'etc', 'all', 'free'],
#  ['bx', 'ip', 'we'],
#  ['pm'],
#  ['dont', 'miss', 'out'],
#  ['sorry', 'll', 'call', 'later', 'in', 'meeting'],
#  ['tell', 'where', 'you', 'reached'],
#  ['yes', 'gauti', 'and', 'sehwag', 'out', 'of', 'odi', 'series'],
#  ['your',
#   'gonna',
#   'have',
#   'to',
#   'pick',
#   'up',
#   'burger',
#   'for',
#   'yourself',
#   'on',
#   'your',
#   'way',
#   'home'],
#  ['can', 'even', 'move'],
#  ['pain', 'is', 'killing', 'me'],
#  ['ha', 'ha', 'ha', 'good', 'joke'],
#  ['girl', 'are', 'situation', 'seekers'],
#  ['it', 'part', 'of', 'checking', 'iq'],
#  ['sorry',
#   'my',
#   'roommate',
#   'took',
#   'forever',
#   'it',
#   'ok',
#   'if',
#   'come',
#   'by',
#   'now'],
#  ['ok',
#   'lar',
#   'double',
#   'check',
#   'wif',
#   'da',
#   'hair',
#   'dresser',
#   'already',
#   'he',
#   'said',
#   'wun',
#   'cut',
#   'short'],
#  ['he', 'said', 'will', 'cut', 'until', 'look', 'nice'],
#  ['valued',
#   'customer',
#   'am',
#   'pleased',
#   'to',
#   'advise',
#   'you',
#   'that',
#   'following',
#   'recent',
#   'review',
#   'of',
#   'your',
#   'mob',
#   'no'],
#  ['you', 'are', 'awarded', 'with', 'bonus', 'prize', 'call'],
#  ['today',
#   'is',
#   'song',
#   'dedicated',
#   'day',
#   'which',
#   'song',
#   'will',
#   'dedicate',
#   'for',
#   'me'],
#  ['send',
#   'this',
#   'to',
#   'all',
#   'ur',
#   'valuable',
#   'frnds',
#   'but',
#   'first',
#   'rply',
#   'me'],
#  ['urgent',
#   'ur',
#   'awarded',
#   'complimentary',
#   'trip',
#   'to',
#   'eurodisinc',
#   'trav',
#   'aco',
#   'entry',
#   'or'],
#  ['to', 'claim', 'txt', 'dis', 'to', 'morefrmmob'],
#  ['ls', 'aj'],
#  ['did', 'you', 'hear', 'about', 'the', 'new', 'divorce', 'barbie'],
#  ['it', 'come', 'with', 'all', 'of', 'ken', 'stuff'],
#  ['plane', 'to', 'give', 'on', 'this', 'month', 'end'],
#  ['wah', 'lucky', 'man', 'then', 'can', 'save', 'money', 'hee'],
#  ['finished', 'class', 'where', 'are', 'you'],
#  ['hi', 'babe', 'im', 'at', 'home', 'now', 'wanna', 'do', 'something'],
#  ['xx'],
#  ['where', 'are', 'you', 'how', 'did', 'you', 'performed'],
#  ['can', 'call', 'me', 'now'],
#  ['am', 'waiting', 'machan'],
#  ['call', 'me', 'once', 'you', 'free'],
#  ['thats', 'cool'],
#  ['am',
#   'gentleman',
#   'and',
#   'will',
#   'treat',
#   'you',
#   'with',
#   'dignity',
#   'and',
#   'respect'],
#  ['like', 'you', 'people', 'very', 'much', 'but', 'am', 'very', 'shy', 'pa'],
#  ['doe', 'not', 'operate', 'after', 'lt', 'gt', 'or', 'what'],
#  ['it', 'not', 'the', 'same', 'here'],
#  ['still', 'looking', 'for', 'job'],
#  ['how', 'much', 'do', 'ta', 'earn', 'there'],
#  ['sorry', 'll', 'call', 'later'],
#  ['did', 'you', 'call', 'me', 'just', 'now', 'ah'],
#  ['ok', 'am', 'on', 'the', 'way', 'to', 'home', 'hi', 'hi'],
#  ['you', 'will', 'be', 'in', 'the', 'place', 'of', 'that', 'man'],
#  ['yup', 'next', 'stop'],
#  ['call', 'you', 'later', 'don', 'have', 'network'],
#  ['if', 'urgnt', 'sm', 'me'],
#  ['for', 'real', 'when', 'getting', 'on', 'yo'],
#  ['only',
#   'need',
#   'more',
#   'ticket',
#   'and',
#   'one',
#   'more',
#   'jacket',
#   'and',
#   'done'],
#  ['already', 'used', 'all', 'my', 'multis'],
#  ['yes',
#   'started',
#   'to',
#   'send',
#   'request',
#   'to',
#   'make',
#   'it',
#   'but',
#   'pain',
#   'came',
#   'back',
#   'so',
#   'back',
#   'in',
#   'bed'],
#  ['double', 'coin', 'at', 'the', 'factory', 'too'],
#  ['gotta', 'cash', 'in', 'all', 'my', 'nitros'],
#  ['really', 'not', 'up', 'to', 'it', 'still', 'tonight', 'babe'],
#  ['ela', 'kano', 'il', 'download', 'come', 'wen', 'ur', 'free'],
#  ['yeah', 'do'],
#  ['don', 'stand', 'to', 'close', 'tho', 'you', 'll', 'catch', 'something'],
#  ['sorry', 'to', 'be', 'pain'],
#  ['is', 'it', 'ok', 'if', 'we', 'meet', 'another', 'night'],
#  ['spent',
#   'late',
#   'afternoon',
#   'in',
#   'casualty',
#   'and',
#   'that',
#   'mean',
#   'haven',
#   'done',
#   'any',
#   'of',
#   'stuff',
#   'moro',
#   'and',
#   'that',
#   'includes',
#   'all',
#   'my',
#   'time',
#   'sheet',
#   'and',
#   'that'],
#  ['sorry'],
#  ['smile',
#   'in',
#   'pleasure',
#   'smile',
#   'in',
#   'pain',
#   'smile',
#   'when',
#   'trouble',
#   'pours',
#   'like',
#   'rain',
#   'smile',
#   'when',
#   'sum',
#   'hurt',
#   'smile',
#   'becoz',
#   'someone',
#   'still',
#   'love',
#   'to',
#   'see',
#   'smiling'],
#  [],
#  ['please',
#   'call',
#   'our',
#   'customer',
#   'service',
#   'representative',
#   'on',
#   'between',
#   'am',
#   'pm',
#   'you',
#   'have',
#   'won',
#   'guaranteed',
#   'cash',
#   'or',
#   'prize'],
#  ['havent', 'planning', 'to', 'buy', 'later'],
#  ['check', 'already', 'lido', 'only', 'got', 'show', 'in', 'afternoon'],
#  ['finish', 'work', 'already'],
#  ['your', 'free', 'ringtone', 'is', 'waiting', 'to', 'be', 'collected'],
#  ['simply', 'text', 'the', 'password', 'mix', 'to', 'to', 'verify'],
#  ['get', 'usher', 'and', 'britney'],
#  ['fml', 'po', 'box', 'mk'],
#  ['ppw'],
#  ['watching', 'telugu', 'movie', 'wat', 'abt'],
#  ['see'],
#  ['when', 'we', 'finish', 'we', 'have', 'load', 'of', 'loan', 'to', 'pay'],
#  ['hi'],
#  ['wk', 'been', 'ok', 'on', 'hols', 'now'],
#  ['yes', 'on', 'for', 'bit', 'of', 'run'],
#  ['forgot',
#   'that',
#   'have',
#   'hairdresser',
#   'appointment',
#   'at',
#   'four',
#   'so',
#   'need',
#   'to',
#   'get',
#   'home',
#   'shower',
#   'beforehand'],
#  ['doe', 'that', 'cause', 'prob', 'for'],
#  ['see', 'cup', 'of', 'coffee', 'animation'],
#  ['please', 'don', 'text', 'me', 'anymore'],
#  ['have', 'nothing', 'else', 'to', 'say'],
#  ['okay', 'name', 'ur', 'price', 'long', 'it', 'legal'],
#  ['wen', 'can', 'pick', 'them', 'up'],
#  ['ave', 'am', 'xx'],
#  ['still', 'looking', 'for', 'car', 'to', 'buy'],
#  ['and', 'have', 'not', 'gone', 'the', 'driving', 'test', 'yet'],
#  ['per',
#   'your',
#   'request',
#   'melle',
#   'melle',
#   'oru',
#   'minnaminunginte',
#   'nurungu',
#   'vettam',
#   'ha',
#   'been',
#   'set',
#   'your',
#   'callertune',
#   'for',
#   'all',
#   'callers'],
#  ['press', 'to', 'copy', 'your', 'friend', 'callertune'],
#  ['wow'],
#  ['you', 're', 'right'],
#  ['didn', 'mean', 'to', 'do', 'that'],
#  ['guess',
#   'once',
#   'gave',
#   'up',
#   'on',
#   'boston',
#   'men',
#   'and',
#   'changed',
#   'my',
#   'search',
#   'location',
#   'to',
#   'nyc',
#   'something',
#   'changed'],
#  ['cuz', 'on', 'my', 'signin', 'page', 'it', 'still', 'say', 'boston'],
#  ['umma', 'my', 'life', 'and', 'vava', 'umma', 'love', 'you', 'lot', 'dear'],
#  ['thanks', 'lot', 'for', 'your', 'wish', 'on', 'my', 'birthday'],
#  ['thanks', 'you', 'for', 'making', 'my', 'birthday', 'truly', 'memorable'],
#  ['aight', 'll', 'hit', 'you', 'up', 'when', 'get', 'some', 'cash'],
#  ['how',
#   'would',
#   'my',
#   'ip',
#   'address',
#   'test',
#   'that',
#   'considering',
#   'my',
#   'computer',
#   'isn',
#   'minecraft',
#   'server'],
#  ['know'],
#  ['grumpy', 'old', 'people'],
#  ['my', 'mom', 'wa', 'like', 'you', 'better', 'not', 'be', 'lying'],
#  ['then', 'again', 'am', 'always', 'the', 'one', 'to', 'play', 'jokes'],
#  ['dont', 'worry'],
#  ['guess', 'he', 'busy'],
#  ['what', 'is', 'the', 'plural', 'of', 'the', 'noun', 'research'],
#  ['going', 'for', 'dinner', 'msg', 'you', 'after'],
#  ['ok', 'wif', 'it', 'co', 'like', 'try', 'new', 'things'],
#  ['but', 'scared', 'dun', 'like', 'mah'],
#  ['co', 'said', 'not', 'too', 'loud'],
#  ['gent'],
#  ['we', 'are', 'trying', 'to', 'contact', 'you'],
#  ['last',
#   'weekend',
#   'draw',
#   'show',
#   'that',
#   'you',
#   'won',
#   'prize',
#   'guaranteed'],
#  ['call', 'claim', 'code'],
#  ['valid', 'hrs', 'only'],
#  ['ppm'],
#  ['wa',
#   'ur',
#   'openin',
#   'sentence',
#   'very',
#   'formal',
#   'anyway',
#   'fine',
#   'too',
#   'juz',
#   'tt',
#   'eatin',
#   'too',
#   'much',
#   'puttin',
#   'on',
#   'weight',
#   'haha',
#   'so',
#   'anythin',
#   'special',
#   'happened'],
#  ['entered', 'my', 'cabin', 'my', 'pa', 'said', 'happy', 'day', 'bos'],
#  [],
#  ['felt', 'special'],
#  ['she', 'askd', 'me', 'lunch'],
#  ['after', 'lunch', 'she', 'invited', 'me', 'to', 'her', 'apartment'],
#  ['we', 'went', 'there'],
#  ['you',
#   'are',
#   'winner',
#   'have',
#   'been',
#   'specially',
#   'selected',
#   'receive',
#   'or',
#   'holiday',
#   'flights',
#   'inc',
#   'speak',
#   'to',
#   'live',
#   'operator',
#   'claim',
#   'min'],
#  ['goodo'],
#  ['yes',
#   'we',
#   'must',
#   'speak',
#   'friday',
#   'egg',
#   'potato',
#   'ratio',
#   'for',
#   'tortilla',
#   'needed'],
#  ['hmm',
#   'my',
#   'uncle',
#   'just',
#   'informed',
#   'me',
#   'that',
#   'he',
#   'paying',
#   'the',
#   'school',
#   'directly'],
#  ['so', 'pls', 'buy', 'food'],
#  ['private'],
#  ['your',
#   'account',
#   'statement',
#   'for',
#   'show',
#   'unredeemed',
#   'bonus',
#   'points'],
#  ['to', 'claim', 'call', 'identifier', 'code', 'expires'],
#  ['urgent'],
#  ['your', 'mobile', 'no'],
#  ['wa',
#   'awarded',
#   'bonus',
#   'caller',
#   'prize',
#   'on',
#   'this',
#   'is',
#   'our',
#   'final',
#   'try',
#   'to',
#   'contact'],
#  ['call', 'from', 'landline', 'box', 'wr', 'ppm'],
#  ['here',
#   'is',
#   'my',
#   'new',
#   'address',
#   'apples',
#   'pairs',
#   'all',
#   'that',
#   'malarky'],
#  ['today',
#   'voda',
#   'number',
#   'ending',
#   'are',
#   'selected',
#   'to',
#   'receive',
#   'award'],
#  ['if',
#   'you',
#   'have',
#   'match',
#   'please',
#   'call',
#   'quoting',
#   'claim',
#   'code',
#   'standard',
#   'rate',
#   'app'],
#  ['am', 'going', 'to', 'sao', 'mu', 'today'],
#  ['will', 'be', 'done', 'only', 'at'],
#  ['predict', 'wat', 'time', 'll', 'finish', 'buying'],
#  ['good', 'stuff', 'will', 'do'],
#  ['just',
#   'so',
#   'that',
#   'you',
#   'know',
#   'yetunde',
#   'hasn',
#   'sent',
#   'money',
#   'yet'],
#  ['just', 'sent', 'her', 'text', 'not', 'to', 'bother', 'sending'],
#  ['so',
#   'it',
#   'over',
#   'you',
#   'dont',
#   'have',
#   'to',
#   'involve',
#   'yourself',
#   'in',
#   'anything'],
#  ['shouldn',
#   'have',
#   'imposed',
#   'anything',
#   'on',
#   'you',
#   'in',
#   'the',
#   'first',
#   'place',
#   'so',
#   'for',
#   'that',
#   'apologise'],
#  ['are', 'you', 'there', 'in', 'room'],
#  ['hey', 'girl'],
#  ['how'],
#  ['hope', 'well', 'me', 'an', 'del', 'bak'],
#  ['again', 'long', 'time', 'no'],
#  ['give', 'me', 'call', 'sum', 'time', 'from', 'lucyxx'],
#  ['how', 'much', 'doe', 'it', 'cost'],
#  ['home'],
#  ['dear', 'will', 'call', 'tmorrow', 'pls', 'accomodate'],
#  ['first', 'answer', 'my', 'question'],
#  ['sunshine', 'quiz', 'wkly'],
#  ['win',
#   'top',
#   'sony',
#   'dvd',
#   'player',
#   'if',
#   'know',
#   'which',
#   'country',
#   'the',
#   'algarve',
#   'is',
#   'in'],
#  ['txt', 'ansr', 'to'],
#  ['sp', 'tyrone'],
#  ['want', 'get', 'laid', 'tonight'],
#  ['want', 'real', 'dogging', 'location', 'sent', 'direct', 'ur', 'mob'],
#  ['join',
#   'the',
#   'uk',
#   'largest',
#   'dogging',
#   'network',
#   'bt',
#   'txting',
#   'gravel',
#   'to'],
#  ['nt'],
#  ['ec'],
#  ['msg'],
#  ['only', 'haf', 'msn'],
#  ['it', 'yijue', 'hotmail', 'com'],
#  ['he', 'is', 'there'],
#  ['you', 'call', 'and', 'meet', 'him'],
#  ['no', 'no'],
#  ['will', 'check', 'all', 'room', 'befor', 'activity'],
#  ['you',
#   'll',
#   'not',
#   'rcv',
#   'any',
#   'more',
#   'msg',
#   'from',
#   'the',
#   'chat',
#   'svc'],
#  ['for',
#   'free',
#   'hardcore',
#   'service',
#   'text',
#   'go',
#   'to',
#   'if',
#   'get',
#   'nothing',
#   'must',
#   'age',
#   'verify',
#   'with',
#   'yr',
#   'network',
#   'try',
#   'again'],
#  ['got',
#   'lazy',
#   'to',
#   'type',
#   'forgot',
#   'in',
#   'lect',
#   'saw',
#   'pouch',
#   'but',
#   'like',
#   'not',
#   'nice'],
#  ['text', 'me', 'when', 'you', 're', 'on', 'the', 'way'],
#  ['sir', 'waiting', 'for', 'your', 'mail'],
#  ['swt',
#   'thought',
#   'nver',
#   'get',
#   'tired',
#   'of',
#   'doing',
#   'little',
#   'thing',
#   'lovable',
#   'persons',
#   'coz',
#   'somtimes',
#   'those',
#   'little',
#   'thing',
#   'occupy',
#   'biggest',
#   'part',
#   'in',
#   'their',
#   'hearts',
#   'gud',
#   'ni'],
#  ['know', 'you', 'are'],
#  ['can', 'you', 'pls', 'open', 'the', 'back'],
#  ['yes', 'see', 'ya', 'not', 'on', 'the', 'dot'],
#  ['whats',
#   'the',
#   'staff',
#   'name',
#   'who',
#   'is',
#   'taking',
#   'class',
#   'for',
#   'us'],
#  ['freemsg', 'why', 'haven', 'you', 'replied', 'to', 'my', 'text'],
#  ['randy', 'sexy', 'female', 'and', 'live', 'local'],
#  ['luv',
#   'to',
#   'hear',
#   'from',
#   'netcollex',
#   'ltd',
#   'per',
#   'msg',
#   'reply',
#   'stop',
#   'to',
#   'end'],
#  ['ummma',
#   'will',
#   'call',
#   'after',
#   'check',
#   'in',
#   'our',
#   'life',
#   'will',
#   'begin',
#   'from',
#   'qatar',
#   'so',
#   'pls',
#   'pray',
#   'very',
#   'hard'],
#  ['deleted', 'my', 'contact', 'that', 'why'],
#  ['sindu', 'got', 'job', 'in', 'birla', 'soft'],
#  ['the', 'wine', 'is', 'flowing', 'and', 'have', 'nevering'],
#  ['yup',
#   'thk',
#   'cine',
#   'is',
#   'better',
#   'co',
#   'no',
#   'need',
#   'go',
#   'down',
#   'plaza',
#   'mah'],
#  ['ok', 'ur', 'typical', 'reply'],
#  ['per',
#   'your',
#   'request',
#   'melle',
#   'melle',
#   'oru',
#   'minnaminunginte',
#   'nurungu',
#   'vettam',
#   'ha',
#   'been',
#   'set',
#   'your',
#   'callertune',
#   'for',
#   'all',
#   'callers'],
#  ['press', 'to', 'copy', 'your', 'friend', 'callertune'],
#  ['you',
#   'are',
#   'everywhere',
#   'dirt',
#   'on',
#   'the',
#   'floor',
#   'the',
#   'windows',
#   'even',
#   'on',
#   'my',
#   'shirt'],
#  ['and',
#   'sometimes',
#   'when',
#   'open',
#   'my',
#   'mouth',
#   'you',
#   'are',
#   'all',
#   'that',
#   'come',
#   'flowing',
#   'out'],
#  ['dream',
#   'of',
#   'my',
#   'world',
#   'without',
#   'you',
#   'then',
#   'half',
#   'my',
#   'chore',
#   'are',
#   'out',
#   'too'],
#  ['time', 'of', 'joy', 'for', 'me', 'lot', 'of', 'tv', 'show', 'll', 'see'],
#  ['but',
#   'guess',
#   'like',
#   'all',
#   'thing',
#   'you',
#   'just',
#   'must',
#   'exist',
#   'like',
#   'rain',
#   'hail',
#   'and',
#   'mist',
#   'and',
#   'when',
#   'my',
#   'time',
#   'here',
#   'is',
#   'done',
#   'you',
#   'and',
#   'become',
#   'one'],
#  ['aaooooright', 'are', 'you', 'at', 'work'],
#  ['leaving', 'my', 'house', 'now'],
#  ['hello', 'my', 'love'],
#  ['what', 'are', 'you', 'doing'],
#  ['did', 'you', 'get', 'to', 'that', 'interview', 'today'],
#  ['are', 'you', 'you', 'happy'],
#  ['are', 'you', 'being', 'good', 'boy'],
#  ['do', 'you', 'think', 'of', 'me', 'are', 'you', 'missing', 'me'],
#  ['customer', 'service', 'annoncement'],
#  ['you', 'have', 'new', 'year', 'delivery', 'waiting', 'for', 'you'],
#  ['please', 'call', 'now', 'to', 'arrange', 'delivery'],
#  ['you',
#   'are',
#   'winner',
#   'have',
#   'been',
#   'specially',
#   'selected',
#   'receive',
#   'cash',
#   'or',
#   'holiday',
#   'flights',
#   'inc',
#   'speak',
#   'to',
#   'live',
#   'operator',
#   'claim'],
#  ['keep',
#   'yourself',
#   'safe',
#   'for',
#   'me',
#   'because',
#   'need',
#   'you',
#   'and',
#   'miss',
#   'you',
#   'already',
#   'and',
#   'envy',
#   'everyone',
#   'that',
#   'see',
#   'you',
#   'in',
#   'real',
#   'life'],
#  ['new', 'car', 'and', 'house', 'for', 'my', 'parents'],
#  ['have', 'only', 'new', 'job', 'in', 'hand'],
#  ['so', 'in', 'love', 'with', 'you'],
#  ['excited', 'each', 'day', 'spend', 'with', 'you'],
#  ['you', 'make', 'me', 'so', 'happy'],
#  ['pls',
#   'stop',
#   'bootydelious',
#   'is',
#   'inviting',
#   'you',
#   'to',
#   'be',
#   'her',
#   'friend'],
#  ['reply',
#   'yes',
#   'or',
#   'no',
#   'see',
#   'her',
#   'www',
#   'sms',
#   'ac',
#   'bootydelious',
#   'stop'],
#  ['send', 'stop', 'frnd', 'to'],
#  ['bangbabes', 'ur', 'order', 'is', 'on', 'the', 'way'],
#  ['should', 'receive', 'service', 'msg', 'download', 'ur', 'content'],
#  ['if', 'do', 'not', 'goto', 'wap'],
#  ['bangb'],
#  ['tv', 'on', 'ur', 'mobile', 'internet', 'service', 'menu'],
#  ['place', 'all', 'ur', 'point', 'on', 'culture', 'module', 'already'],
#  ['urgent'],
#  ['we', 'are', 'trying', 'to', 'contact', 'you'],
#  ['last',
#   'weekend',
#   'draw',
#   'show',
#   'that',
#   'you',
#   'have',
#   'won',
#   'prize',
#   'guaranteed'],
#  ['call', 'claim', 'code'],
#  ['valid', 'hrs', 'only'],
#  ['hi',
#   'frnd',
#   'which',
#   'is',
#   'best',
#   'way',
#   'to',
#   'avoid',
#   'missunderstding',
#   'wit',
#   'our',
#   'beloved',
#   'one'],
#  ['great', 'escape'],
#  ['fancy', 'the', 'bridge', 'but', 'need', 'her', 'lager'],
#  ['see', 'you', 'tomo'],
#  ['yes',
#   'it',
#   'completely',
#   'in',
#   'out',
#   'of',
#   'form',
#   'clark',
#   'also',
#   'utter',
#   'waste'],
#  ['sir', 'need', 'axis', 'bank', 'account', 'no', 'and', 'bank', 'address'],
#  ['hmmm',
#   'thk',
#   'sure',
#   'got',
#   'time',
#   'to',
#   'hop',
#   'ard',
#   'ya',
#   'can',
#   'go',
#   'free',
#   'abt',
#   'muz',
#   'call',
#   'to',
#   'discus',
#   'liao'],
#  ['what', 'time', 'you', 'coming', 'down', 'later'],
#  ['bloody', 'hell', 'cant', 'believe', 'you', 'forgot', 'my', 'surname', 'mr'],
#  ['ill', 'give', 'clue', 'it', 'spanish', 'and', 'begin', 'with'],
#  ['well', 'gonna', 'finish', 'my', 'bath', 'now'],
#  ['have', 'good', 'fine', 'night'],
#  ['let',
#   'me',
#   'know',
#   'when',
#   'you',
#   've',
#   'got',
#   'the',
#   'money',
#   'so',
#   'carlos',
#   'can',
#   'make',
#   'the',
#   'call'],
#  ['still', 'going', 'to', 'the', 'mall'],
#  ['turn',
#   'out',
#   'my',
#   'friend',
#   'are',
#   'staying',
#   'for',
#   'the',
#   'whole',
#   'show',
#   'and',
#   'won',
#   'be',
#   'back',
#   'til',
#   'lt',
#   'gt',
#   'so',
#   'feel',
#   'free',
#   'to',
#   'go',
#   'ahead',
#   'and',
#   'smoke',
#   'that',
#   'lt',
#   'gt',
#   'worth'],
#  ['text', 'her'],
#  ['if',
#   'she',
#   'doesnt',
#   'reply',
#   'let',
#   'me',
#   'know',
#   'so',
#   'can',
#   'have',
#   'her',
#   'log',
#   'in'],
#  ['hi'],
#  ['you',
#   'just',
#   'spoke',
#   'to',
#   'maneesha',
#   'we',
#   'like',
#   'to',
#   'know',
#   'if',
#   'you',
#   'were',
#   'satisfied',
#   'with',
#   'the',
#   'experience'],
#  ['reply', 'toll', 'free', 'with', 'yes', 'or', 'no'],
#  ['you', 'lifted', 'my', 'hope', 'with', 'the', 'offer', 'of', 'money'],
#  ['am', 'in', 'need'],
#  ['especially',
#   'when',
#   'the',
#   'end',
#   'of',
#   'the',
#   'month',
#   'approach',
#   'and',
#   'it',
#   'hurt',
#   'my',
#   'studying'],
#  ['anyways', 'have', 'gr', 'weekend'],
#  ['lol', 'no'],
#  ['can', 'trust', 'me'],
#  ['ok',
#   'am',
#   'gentleman',
#   'and',
#   'will',
#   'treat',
#   'you',
#   'with',
#   'dignity',
#   'and',
#   'respect'],
#  ['he', 'will', 'you', 'guy', 'close'],
#  ['going', 'on', 'nothing', 'great', 'bye'],
#  ['hello', 'handsome'],
#  ['are', 'you', 'finding', 'that', 'job'],
#  ['not', 'being', 'lazy'],
#  ['working', 'towards', 'getting', 'back', 'that', 'net', 'for', 'mummy'],
#  ['where', 'my', 'boytoy', 'now'],
#  ['doe', 'he', 'miss', 'me'],
#  ['haha', 'awesome', 'be', 'there', 'in', 'minute'],
#  ['please',
#   'call',
#   'our',
#   'customer',
#   'service',
#   'representative',
#   'on',
#   'freephone',
#   'between',
#   'am',
#   'pm',
#   'you',
#   'have',
#   'won',
#   'guaranteed',
#   'cash',
#   'or',
#   'prize'],
#  ['have', 'you', 'got', 'xmas', 'radio', 'times'],
#  ['if', 'not', 'will', 'get', 'it', 'now'],
#  ['jus', 'reached', 'home'],
#  ['go', 'bathe', 'first'],
#  ['but', 'my', 'si', 'using', 'net', 'tell', 'when', 'she', 'finish'],
#  ['are', 'you', 'unique', 'enough'],
#  ['find', 'out', 'from', 'th', 'august'],
#  ['www', 'areyouunique', 'co', 'uk'],
#  ['sorry'],
#  ['ve',
#   'joined',
#   'the',
#   'league',
#   'of',
#   'people',
#   'that',
#   'dont',
#   'keep',
#   'in',
#   'touch'],
#  ['you', 'mean', 'great', 'deal', 'to', 'me'],
#  ['you',
#   'have',
#   'been',
#   'friend',
#   'at',
#   'all',
#   'time',
#   'even',
#   'at',
#   'great',
#   'personal',
#   'cost'],
#  ['do', 'have', 'great', 'week'],
#  ['hi', 'finally', 'completed', 'the', 'course'],
#  ['it', 'will', 'stop', 'on', 'itself'],
#  ['however',
#   'suggest',
#   'she',
#   'stay',
#   'with',
#   'someone',
#   'that',
#   'will',
#   'be',
#   'able',
#   'to',
#   'give',
#   'or',
#   'for',
#   'every',
#   'stool'],
#  ['how', 'are', 'you', 'doing'],
#  ['hope', 'you', 've', 'settled', 'in', 'for', 'the', 'new', 'school', 'year'],
#  ['just', 'wishin', 'you', 'gr', 'day'],
#  ['gud', 'mrng', 'dear', 'hav', 'nice', 'day'],
#  ['did', 'got', 'that', 'person', 'story'],
#  ['is', 'your', 'hamster', 'dead'],
#  ['hey', 'so', 'tmr', 'meet', 'you', 'at', 'pm', 'orchard', 'mrt'],
#  ['hi', 'it', 'kate', 'how', 'is', 'your', 'evening'],
#  ['hope',
#   'can',
#   'see',
#   'you',
#   'tomorrow',
#   'for',
#   'bit',
#   'but',
#   'have',
#   'to',
#   'bloody',
#   'babyjontet'],
#  ['txt', 'back', 'if', 'can'],
#  ['xxx'],
#  ['found', 'it', 'enc', 'lt', 'gt', 'where', 'you', 'at'],
#  ['sent', 'you', 'lt', 'gt', 'buck'],
#  ['hello',
#   'darlin',
#   'ive',
#   'finished',
#   'college',
#   'now',
#   'so',
#   'txt',
#   'me',
#   'when',
#   'finish',
#   'if',
#   'can',
#   'love',
#   'kate',
#   'xxx'],
#  ['your',
#   'account',
#   'ha',
#   'been',
#   'refilled',
#   'successfully',
#   'by',
#   'inr',
#   'lt',
#   'decimal',
#   'gt'],
#  ['your',
#   'keralacircle',
#   'prepaid',
#   'account',
#   'balance',
#   'is',
#   'lt',
#   'decimal',
#   'gt'],
#  ['your', 'transaction', 'id', 'is', 'kr', 'lt', 'gt'],
#  ['goodmorning', 'sleeping', 'ga'],
#  ['call', 'me', 'alter', 'at', 'ok'],
#  ['say',
#   'until',
#   'like',
#   'dat',
#   'dun',
#   'buy',
#   'ericsson',
#   'oso',
#   'cannot',
#   'oredi',
#   'lar'],
#  ['entered', 'my', 'cabin', 'my', 'pa', 'said', 'happy', 'day', 'bos'],
#  [],
#  ['felt', 'special'],
#  ['she', 'askd', 'me', 'lunch'],
#  ['after', 'lunch', 'she', 'invited', 'me', 'to', 'her', 'apartment'],
#  ['we', 'went', 'there'],
#  ['aight', 'yo', 'dat', 'straight', 'dogg'],
#  ['you',
#   'please',
#   'give',
#   'connection',
#   'today',
#   'itself',
#   'before',
#   'lt',
#   'decimal',
#   'gt',
#   'or',
#   'refund',
#   'the',
#   'bill'],
#  ['both', 'shoot', 'big', 'load', 'so', 'get', 'ready'],
#  ['what', 'up', 'bruv', 'hope', 'you', 'had', 'great', 'break'],
#  ['do', 'have', 'rewarding', 'semester'],
#  ['home', 'so', 'we', 'can', 'always', 'chat'],
#  ['good', 'study', 'well'],
#  ['yup', 'how', 'noe', 'leh'],
#  ['sound', 'great'],
#  ['are', 'you', 'home', 'now'],
#  ['finally',
#   'the',
#   'match',
#   'heading',
#   'towards',
#   'draw',
#   'your',
#   'prediction'],
#  ['tired'],
#  ['haven', 'slept', 'well', 'the', 'past', 'few', 'nights'],
#  ['easy', 'ah', 'sen', 'got', 'selected', 'mean', 'it', 'good'],
#  ['have', 'to', 'take', 'exam', 'with', 'march'],
#  ['yeah', 'you', 'should'],
#  ['think', 'you', 'can', 'use', 'your', 'gt', 'atm', 'now', 'to', 'register'],
#  ['not',
#   'sure',
#   'but',
#   'if',
#   'there',
#   'anyway',
#   'can',
#   'help',
#   'let',
#   'me',
#   'know'],
#  ['but', 'when', 'you', 'do', 'be', 'sure', 'you', 'are', 'ready'],
#  ['ok', 'no', 'prob'],
#  ['take', 'ur', 'time'],
#  ['there',
#   'is',
#   'called',
#   'ubandu',
#   'which',
#   'will',
#   'run',
#   'without',
#   'installing',
#   'in',
#   'hard',
#   'disk',
#   'you',
#   'can',
#   'use',
#   'that',
#   'to',
#   'copy',
#   'the',
#   'important',
#   'file',
#   'in',
#   'system',
#   'and',
#   'give',
#   'it',
#   'to',
#   'repair',
#   'shop'],
#  ['sorry', 'll', 'call', 'later'],
#  ['say', 'leh', 'of', 'course', 'nothing', 'happen', 'lar'],
#  ['not', 'say', 'romantic', 'jus', 'bit', 'only', 'lor'],
#  ['thk', 'nite', 'scenery', 'not', 'so', 'nice', 'leh'],
#  ['new', 'mobile', 'from', 'must', 'go'],
#  ['txt',
#   'nokia',
#   'to',
#   'no',
#   'collect',
#   'yours',
#   'today',
#   'from',
#   'only',
#   'www',
#   'tc',
#   'biz',
#   'optout',
#   'gbp',
#   'mtmsg'],
#  ['would', 'really', 'appreciate', 'if', 'you', 'call', 'me'],
#  ['just', 'need', 'someone', 'to', 'talk', 'to'],
#  ['will', 'meet', 'ur', 'dream', 'partner', 'soon'],
#  ['is', 'ur', 'career', 'off', 'flyng', 'start'],
#  ['find',
#   'out',
#   'free',
#   'txt',
#   'horo',
#   'followed',
#   'by',
#   'ur',
#   'star',
#   'sign',
#   'horo',
#   'aries'],
#  ['hey', 'company', 'elama', 'po', 'mudyadhu'],
#  ['life',
#   'is',
#   'more',
#   'strict',
#   'than',
#   'teacher',
#   'bcoz',
#   'teacher',
#   'teach',
#   'lesson',
#   'amp',
#   'then',
#   'conduct',
#   'exam',
#   'but',
#   'life',
#   'first',
#   'conduct',
#   'exam',
#   'amp',
#   'then',
#   'teach',
#   'lessons'],
#  ['happy', 'morning'],
#  [],
#  [],
#  ['dear', 'good', 'morning', 'now', 'only', 'am', 'up'],
#  ['get',
#   'down',
#   'in',
#   'gandhipuram',
#   'and',
#   'walk',
#   'to',
#   'cross',
#   'cut',
#   'road'],
#  ['right',
#   'side',
#   'lt',
#   'gt',
#   'street',
#   'road',
#   'and',
#   'turn',
#   'at',
#   'first',
#   'right'],
#  ['dear', 'we', 'are', 'going', 'to', 'our', 'rubber', 'place'],
#  ['sorry', 'battery', 'died', 'yeah', 'here'],
#  ['yes', 'here', 'tv', 'is', 'always', 'available', 'in', 'work', 'place'],
#  ['text', 'meet', 'someone', 'sexy', 'today'],
#  ['can',
#   'find',
#   'date',
#   'or',
#   'even',
#   'flirt',
#   'it',
#   'up',
#   'to',
#   'join',
#   'just'],
#  ['reply', 'with', 'name', 'age', 'eg', 'sam'],
#  ['msg', 'recd', 'thirtyeight', 'penny'],
#  ['have', 'printed', 'it', 'oh'],
#  ['so', 'lt', 'gt', 'come', 'upstairs'],
#  ['or',
#   'ill',
#   'be',
#   'little',
#   'closer',
#   'like',
#   'at',
#   'the',
#   'bus',
#   'stop',
#   'on',
#   'the',
#   'same',
#   'street'],
#  ['where', 'are', 'you', 'when', 'wil', 'you', 'reach', 'here'],
#  ['new',
#   'theory',
#   'argument',
#   'win',
#   'situation',
#   'but',
#   'loses',
#   'the',
#   'person'],
#  ['so', 'dont', 'argue', 'with', 'ur', 'friend', 'just'],
#  [],
#  [],
#  ['kick', 'them', 'amp', 'say', 'always', 'correct'],
#  [],
#  ['have',
#   'secret',
#   'admirer',
#   'who',
#   'is',
#   'looking',
#   'make',
#   'contact',
#   'with',
#   'find',
#   'out',
#   'who',
#   'they',
#   'reveal',
#   'who',
#   'think',
#   'ur',
#   'so',
#   'special',
#   'call',
#   'on'],
#  ['tomarrow', 'final', 'hearing', 'on', 'my', 'laptop', 'case', 'so', 'cant'],
#  ['tel', 'me', 'avent', 'done', 'sportsx'],
#  ['okay'],
#  ['no', 'no', 'just', 'shining', 'on'],
#  ['that',
#   'wa',
#   'meant',
#   'to',
#   'be',
#   'signing',
#   'but',
#   'that',
#   'sound',
#   'better'],
#  ['although',
#   'told',
#   'dat',
#   'into',
#   'baig',
#   'face',
#   'watch',
#   'now',
#   'but',
#   'really',
#   'like',
#   'watch',
#   'gave',
#   'co',
#   'it',
#   'fr',
#   'thanx',
#   'everything',
#   'dat',
#   've',
#   'done',
#   'today',
#   'touched'],
#  ['don', 'remember', 'that', 'old', 'commercial'],
#  ['too', 'late'],
#  ['said', 'have', 'the', 'website'],
#  ['didn', 'have', 'or', 'dont', 'have', 'the', 'slipper'],
#  ['asked', 'you', 'to', 'call', 'him', 'now', 'ok'],
#  ['kallis', 'wont', 'bat', 'in', 'nd', 'innings'],
#  ['it', 'didnt', 'work', 'again', 'oh'],
#  ['ok', 'goodnight', 'then'],
#  ['ll',
#   'fix',
#   'and',
#   'have',
#   'it',
#   'ready',
#   'by',
#   'the',
#   'time',
#   'you',
#   'wake',
#   'up'],
#  ['you', 'are', 'very', 'dearly', 'missed', 'have', 'good', 'night', 'sleep'],
#  ['congratulation',
#   'ur',
#   'awarded',
#   'of',
#   'cd',
#   'voucher',
#   'or',
#   'gift',
#   'guaranteed',
#   'free',
#   'entry',
#   'wkly',
#   'draw',
#   'txt',
#   'music',
#   'to',
#   'tncs',
#   'www',
#   'ldew',
#   'com',
#   'win',
#   'ppmx',
#   'age'],
#  ['ranjith', 'cal', 'drpd', 'deeraj', 'and', 'deepak', 'min', 'hold'],
#  ['wen',
#   'ur',
#   'lovable',
#   'bcums',
#   'angry',
#   'wid',
#   'dnt',
#   'take',
#   'it',
#   'seriously',
#   'coz',
#   'being',
#   'angry',
#   'is',
#   'most',
#   'childish',
#   'true',
#   'way',
#   'of',
#   'showing',
#   'deep',
#   'affection',
#   'care',
#   'luv'],
#  ['kettoda', 'manda', 'have', 'nice', 'day', 'da'],
#  ['what', 'you', 'doing', 'how', 'are', 'you'],
#  ['ups',
#   'which',
#   'is',
#   'days',
#   'also',
#   'and',
#   'the',
#   'shipping',
#   'company',
#   'that',
#   'take',
#   'wks'],
#  ['the',
#   'other',
#   'way',
#   'is',
#   'usps',
#   'which',
#   'take',
#   'week',
#   'but',
#   'when',
#   'it',
#   'get',
#   'to',
#   'lag',
#   'you',
#   'may',
#   'have',
#   'to',
#   'bribe',
#   'nipost',
#   'to',
#   'get',
#   'your',
#   'stuff'],
#  ['back', 'lemme', 'know', 'when', 'you', 're', 'ready'],
#  ['don',
#   'necessarily',
#   'expect',
#   'it',
#   'to',
#   'be',
#   'done',
#   'before',
#   'you',
#   'get',
#   'back',
#   'though',
#   'because',
#   'just',
#   'now',
#   'headin',
#   'out'],
#  ['mmm', 'so', 'yummy', 'babe', 'nice', 'jolt', 'to', 'the', 'suzy'],
#  ['where', 'are', 'you', 'lover'],
#  ['need', 'you'],
#  ['we',
#   'tried',
#   'to',
#   'contact',
#   'you',
#   're',
#   'your',
#   'reply',
#   'to',
#   'our',
#   'offer',
#   'of',
#   'video',
#   'handset'],
#  ['anytime', 'network', 'mins'],
#  ['unlimited', 'text'],
#  ['camcorder'],
#  ['reply', 'or', 'call', 'now'],
#  ['parked', 'next', 'to', 'mini'],
#  ['when', 'are', 'you', 'coming', 'in', 'today', 'do', 'you', 'think'],
#  ['yup'],
#  ['anyway', 'going', 'shopping', 'on', 'my', 'own', 'now'],
#  ['co', 'my', 'si', 'not', 'done', 'yet'],
#  ['dun', 'disturb', 'liao'],
#  ['my', 'no'],
#  ['in', 'luton', 'ring', 'me', 'if', 'ur', 'around'],
#  [],
#  ['hey',
#   'am',
#   'really',
#   'horny',
#   'want',
#   'to',
#   'chat',
#   'or',
#   'see',
#   'me',
#   'naked',
#   'text',
#   'hot',
#   'to',
#   'text',
#   'charged',
#   'at',
#   'pm',
#   'to',
#   'unsubscribe',
#   'text',
#   'stop'],
#  ['why', 'you', 'dint', 'come', 'with', 'us'],
#  ['same'],
#  ['wana', 'plan', 'trip', 'sometme', 'then'],
#  ['not', 'sure', 'yet', 'still', 'trying', 'to', 'get', 'hold', 'of', 'him'],
#  ['ur', 'ringtone', 'service', 'ha', 'changed'],
#  ['free', 'credits'],
#  ['go', 'to', 'club', 'mobiles', 'com', 'to', 'choose', 'content', 'now'],
#  ['stop'],
#  ['txt', 'club', 'stop', 'to'],
#  ['wk', 'club', 'po', 'box', 'mk', 'wt'],
#  ['the', 'evo'],
#  ['just', 'had', 'to', 'download', 'flash'],
#  ['jealous'],
#  ['ringtone',
#   'club',
#   'get',
#   'the',
#   'uk',
#   'single',
#   'chart',
#   'on',
#   'your',
#   'mobile',
#   'each',
#   'week',
#   'and',
#   'choose',
#   'any',
#   'top',
#   'quality',
#   'ringtone'],
#  ['this', 'message', 'is', 'free', 'of', 'charge'],
#  ['come',
#   'to',
#   'mu',
#   'we',
#   're',
#   'sorting',
#   'out',
#   'our',
#   'narcotic',
#   'situation'],
#  ['night',
#   'ha',
#   'ended',
#   'for',
#   'another',
#   'day',
#   'morning',
#   'ha',
#   'come',
#   'in',
#   'special',
#   'way'],
#  ['may',
#   'you',
#   'smile',
#   'like',
#   'the',
#   'sunny',
#   'ray',
#   'and',
#   'leaf',
#   'your',
#   'worry',
#   'at',
#   'the',
#   'blue',
#   'blue',
#   'bay'],
#  ['hmv',
#   'bonus',
#   'special',
#   'pound',
#   'of',
#   'genuine',
#   'hmv',
#   'voucher',
#   'to',
#   'be',
#   'won'],
#  ['just', 'answer', 'easy', 'questions'],
#  ['play', 'now'],
#  ['send', 'hmv', 'to', 'more', 'info', 'www', 'percent', 'real', 'com'],
#  ['usf', 'guess', 'might', 'well', 'take', 'car'],
#  ['no', 'objection'],
#  ['my', 'bf', 'not', 'coming'],
#  ['thanx'],
#  ['tell', 'rob', 'to', 'mack', 'his', 'gf', 'in', 'the', 'theater'],
#  ['awesome', 'll', 'see', 'you', 'in', 'bit'],
#  ['just', 'sent', 'it'],
#  ['so', 'what', 'type', 'of', 'food', 'do', 'you', 'like'],
#  ['all', 'done'],
#  ['all', 'handed', 'in'],
#  ['celebration', 'in', 'full', 'swing', 'yet'],
#  ['you', 'got', 'called', 'tool'],
#  ['wen',
#   'miss',
#   'someone',
#   'the',
#   'person',
#   'is',
#   'definitely',
#   'special',
#   'for',
#   'but',
#   'if',
#   'the',
#   'person',
#   'is',
#   'so',
#   'special',
#   'why',
#   'to',
#   'miss',
#   'them',
#   'just',
#   'keep',
#   'in',
#   'touch',
#   'gdeve'],
#  ['ok', 'asked', 'for', 'money', 'how', 'far'],
#  ['okie'],
#  ['yeah',
#   'think',
#   'my',
#   'usual',
#   'guy',
#   'still',
#   'passed',
#   'out',
#   'from',
#   'last',
#   'night',
#   'if',
#   'you',
#   'get',
#   'ahold',
#   'of',
#   'anybody',
#   'let',
#   'me',
#   'know',
#   'and',
#   'll',
#   'throw',
#   'down'],
#  ['might',
#   'come',
#   'by',
#   'tonight',
#   'then',
#   'if',
#   'my',
#   'class',
#   'let',
#   'out',
#   'early'],
#  ['ok'],
#  ['hi', 'baby', 'im', 'cruisin', 'with', 'my', 'girl', 'friend', 'what', 'up'],
#  ['give',
#   'me',
#   'call',
#   'in',
#   'and',
#   'hour',
#   'at',
#   'home',
#   'if',
#   'thats',
#   'alright',
#   'or',
#   'fone',
#   'me',
#   'on',
#   'this',
#   'fone',
#   'now',
#   'love',
#   'jenny',
#   'xxx'],
#  ['my',
#   'life',
#   'mean',
#   'lot',
#   'to',
#   'me',
#   'not',
#   'because',
#   'love',
#   'my',
#   'life',
#   'but',
#   'because',
#   'love',
#   'the',
#   'people',
#   'in',
#   'my',
#   'life',
#   'the',
#   'world',
#   'call',
#   'them',
#   'friends',
#   'call',
#   'them',
#   'my',
#   'world',
#   'ge'],
#  ['dear',
#   'shall',
#   'mail',
#   'tonite',
#   'busy',
#   'in',
#   'the',
#   'street',
#   'shall',
#   'update',
#   'you',
#   'tonite',
#   'things',
#   'are',
#   'looking',
#   'ok',
#   'varunnathu',
#   'edukkukayee',
#   'raksha',
#   'ollu',
#   'but',
#   'good',
#   'one',
#   'in',
#   'real',
#   'sense'],
#  ['hey', 'you', 'told', 'your', 'name', 'to', 'gautham', 'ah'],
#  ['haf', 'found', 'him'],
#  ['feel', 'so', 'stupid', 'da', 'cam', 'wa', 'working'],
#  ['oops'],
#  ['got', 'that', 'bit'],
#  ['are', 'you', 'this', 'much', 'buzy'],
#  ['accidentally', 'deleted', 'the', 'message'],
#  ['resend', 'please'],
#  ['mobile',
#   'customer',
#   'you',
#   'may',
#   'now',
#   'claim',
#   'your',
#   'free',
#   'camera',
#   'phone',
#   'upgrade',
#   'pay',
#   'go',
#   'sim',
#   'card',
#   'for',
#   'your',
#   'loyalty'],
#  ['call', 'on', 'offer', 'end', 'thfeb', 'apply'],
#  ['unless',
#   'it',
#   'situation',
#   'where',
#   'you',
#   'go',
#   'gurl',
#   'would',
#   'be',
#   'more',
#   'appropriate'],
#  ['hurt',
#   'me',
#   'tease',
#   'me',
#   'make',
#   'me',
#   'cry',
#   'but',
#   'in',
#   'the',
#   'end',
#   'of',
#   'my',
#   'life',
#   'when',
#   'die',
#   'plz',
#   'keep',
#   'one',
#   'rose',
#   'on',
#   'my',
#   'grave',
#   'and',
#   'say',
#   'stupid',
#   'miss',
#   'have',
#   'nice',
#   'day',
#   'bslvyl'],
#  ['cant', 'pick', 'the', 'phone', 'right', 'now'],
#  ['pls', 'send', 'message'],
#  ['need',
#   'coffee',
#   'run',
#   'tomo',
#   'can',
#   'believe',
#   'it',
#   'that',
#   'time',
#   'of',
#   'week',
#   'already'],
#  ['awesome',
#   'remember',
#   'the',
#   'last',
#   'time',
#   'we',
#   'got',
#   'somebody',
#   'high',
#   'for',
#   'the',
#   'first',
#   'time',
#   'with',
#   'diesel'],
#  ['shit',
#   'that',
#   'is',
#   'really',
#   'shocking',
#   'and',
#   'scary',
#   'cant',
#   'imagine',
#   'for',
#   'second'],
#  ['def', 'up', 'for', 'night', 'out'],
#  ['do',
#   'think',
#   'there',
#   'is',
#   'somewhere',
#   'could',
#   'crash',
#   'for',
#   'night',
#   'save',
#   'on',
#   'taxi'],
#  ['oh',
#   'and',
#   'by',
#   'the',
#   'way',
#   'you',
#   'do',
#   'have',
#   'more',
#   'food',
#   'in',
#   'your',
#   'fridge'],
#  ['want', 'to', 'go', 'out', 'for', 'meal', 'tonight'],
#  ['he', 'is', 'womdarfull', 'actor'],
#  ['sms'],
#  ['ac', 'blind', 'date'],
#  ['rodds', 'is', 'from', 'aberdeen', 'united', 'kingdom'],
#  ['check', 'him', 'out', 'http', 'img'],
#  ['sms'],
#  ['ac', 'icmb', 'cktz', 'no', 'blind', 'date', 'send', 'hide'],
#  ['yup', 'from', 'what', 'remb', 'think', 'should', 'be', 'can', 'book'],
#  ['jos', 'ask', 'if', 'wana', 'meet', 'up'],
#  ['lol', 'yes'],
#  ['our',
#   'friendship',
#   'is',
#   'hanging',
#   'on',
#   'thread',
#   'cause',
#   'won',
#   'buy',
#   'stuff'],
#  ['themob',
#   'check',
#   'out',
#   'our',
#   'newest',
#   'selection',
#   'of',
#   'content',
#   'games',
#   'tones',
#   'gossip',
#   'babe',
#   'and',
#   'sport',
#   'keep',
#   'your',
#   'mobile',
#   'fit',
#   'and',
#   'funky',
#   'text',
#   'wap',
#   'to'],
#  ['where', 'are', 'the', 'garage', 'keys'],
#  ['they', 'aren', 'on', 'the', 'bookshelf'],
#  ['today', 'is', 'accept', 'day', 'accept', 'me', 'as'],
#  ['brother',
#   'sister',
#   'lover',
#   'dear',
#   'best',
#   'clos',
#   'lvblefrnd',
#   'jstfrnd',
#   'cutefrnd',
#   'lifpartnr',
#   'belovd',
#   'swtheart',
#   'bstfrnd',
#   'no',
#   'rply',
#   'mean',
#   'enemy'],
#  ['think', 'ur', 'smart'],
#  ['win',
#   'this',
#   'week',
#   'in',
#   'our',
#   'weekly',
#   'quiz',
#   'text',
#   'play',
#   'to',
#   'now',
#   'cs',
#   'winnersclub',
#   'po',
#   'box',
#   'uz'],
#  [],
#  ['gbp', 'week'],
#  ['he',
#   'say',
#   'he',
#   'll',
#   'give',
#   'me',
#   'call',
#   'when',
#   'his',
#   'friend',
#   'got',
#   'the',
#   'money',
#   'but',
#   'that',
#   'he',
#   'definitely',
#   'buying',
#   'before',
#   'the',
#   'end',
#   'of',
#   'the',
#   'week'],
#  ['hi',
#   'the',
#   'way',
#   'wa',
#   'with',
#   'day',
#   'is',
#   'the',
#   'normal',
#   'way',
#   'this',
#   'is',
#   'the',
#   'real',
#   'me'],
#  ['ur', 'unique', 'hope', 'know', 'the', 'rest', 'of', 'mylife'],
#  ['hope', 'find', 'wot', 'wa', 'lost'],
#  ['you', 'made', 'my', 'day'],
#  ['do', 'have', 'great', 'day', 'too'],
#  ['advance', 'happy', 'pongal'],
#  ['hmmm',
#   'guess',
#   'we',
#   'can',
#   'go',
#   'kb',
#   'power',
#   'yoga',
#   'haha',
#   'dunno',
#   'we',
#   'can',
#   'tahan',
#   'power',
#   'yoga',
#   'anot',
#   'thk',
#   'got',
#   'lo',
#   'oso',
#   'forgot',
#   'liao'],
#  ['not', 'really', 'dude', 'have', 'no', 'friend', 'afraid'],
#  ['december', 'only'],
#  ['had', 'your', 'mobile', 'mths'],
#  ['you',
#   'are',
#   'entitled',
#   'to',
#   'update',
#   'to',
#   'the',
#   'latest',
#   'colour',
#   'camera',
#   'mobile',
#   'for',
#   'free'],
#  ['call', 'the', 'mobile', 'update', 'co', 'free', 'on'],
#  ['coffee', 'cake', 'guess'],
#  ['merry', 'christmas', 'to', 'you', 'too', 'babe', 'love', 'ya', 'kisses'],
#  ['hey',
#   'why',
#   'dont',
#   'we',
#   'just',
#   'go',
#   'watch',
#   'men',
#   'and',
#   'have',
#   'lunch',
#   'haha'],
#  ['cud',
#   'tell',
#   'ppl',
#   'im',
#   'gona',
#   'bit',
#   'co',
#   'bus',
#   'hav',
#   'gon',
#   'past',
#   'co',
#   'they',
#   'were',
#   'full',
#   'im',
#   'still',
#   'waitin',
#   'pete'],
#  ['that', 'would', 'be', 'great'],
#  ['we', 'll', 'be', 'at', 'the', 'guild'],
#  ['could',
#   'meet',
#   'on',
#   'bristol',
#   'road',
#   'or',
#   'somewhere',
#   'will',
#   'get',
#   'in',
#   'touch',
#   'over',
#   'weekend'],
#  ['our', 'plan', 'take', 'flight'],
#  ['have', 'good', 'week'],
#  ['no', 'problem'],
#  ['how', 'are', 'you', 'doing'],
#  ['no', 'calls', 'messages', 'missed', 'call'],
#  ['hi', 'da', 'how', 'is', 'the', 'today', 'class'],
#  ['say',
#   'that',
#   'good',
#   'sign',
#   'but',
#   'well',
#   'you',
#   'know',
#   'my',
#   'track',
#   'record',
#   'at',
#   'reading',
#   'woman'],
#  ['cool', 'text', 'me', 'when', 'you', 're', 'parked'],
#  ['reading', 'the', 'text', 'just', 'sent', 'you'],
#  ['it', 'meant', 'to', 'be', 'joke'],
#  ['so', 'read', 'it', 'in', 'that', 'light'],
#  ['apo', 'good', 'movie'],
#  ['maybe',
#   'could',
#   'get',
#   'book',
#   'out',
#   'tomo',
#   'then',
#   'return',
#   'it',
#   'immediately'],
#  ['or', 'something'],
#  ['call', 'germany', 'for', 'only', 'penny', 'per', 'minute'],
#  ['call',
#   'from',
#   'fixed',
#   'line',
#   'via',
#   'access',
#   'number',
#   'no',
#   'prepayment'],
#  ['direct', 'access'],
#  ['any',
#   'chance',
#   'you',
#   'might',
#   'have',
#   'had',
#   'with',
#   'me',
#   'evaporated',
#   'soon',
#   'you',
#   'violated',
#   'my',
#   'privacy',
#   'by',
#   'stealing',
#   'my',
#   'phone',
#   'number',
#   'from',
#   'your',
#   'employer',
#   'paperwork'],
#  ['not', 'cool', 'at', 'all'],
#  ['please',
#   'do',
#   'not',
#   'contact',
#   'me',
#   'again',
#   'or',
#   'will',
#   'report',
#   'you',
#   'to',
#   'your',
#   'supervisor'],
#  ['valentine', 'day', 'special'],
#  ['win',
#   'over',
#   'in',
#   'our',
#   'quiz',
#   'and',
#   'take',
#   'your',
#   'partner',
#   'on',
#   'the',
#   'trip',
#   'of',
#   'lifetime'],
#  ['send', 'go', 'to', 'now'],
#  ['msg', 'rcvd'],
#  ['custcare'],
#  ['ta', 'daaaaa'],
#  ['am', 'home', 'babe', 'are', 'you', 'still', 'up'],
#  ['cool'],
#  ['so',
#   'how',
#   'come',
#   'you',
#   'havent',
#   'been',
#   'wined',
#   'and',
#   'dined',
#   'before'],
#  ['just', 'sleeping', 'and', 'surfing'],
#  ['sorry', 'll', 'call', 'later'],
#  ['calling', 'me', 'right'],
#  ['call', 'my', 'hand', 'phone'],
#  ['ok', 'that', 'great', 'thanx', 'lot'],
#  ['take', 'it', 'the', 'post', 'ha', 'come', 'then'],
#  ['you', 'must', 'have', 'of', 'text', 'now'],
#  ['happy', 'reading'],
#  ['my',
#   'one',
#   'from',
#   'wiv',
#   'hello',
#   'caroline',
#   'at',
#   'the',
#   'end',
#   'is',
#   'my',
#   'favourite'],
#  ['bless', 'him'],
#  ['where', 'been', 'hiding', 'stranger'],
#  ['am', 'not', 'interested', 'to', 'do', 'like', 'that'],
#  ['my',
#   'sister',
#   'cleared',
#   'two',
#   'round',
#   'in',
#   'birla',
#   'soft',
#   'yesterday'],
#  ['gudnite', 'tc', 'practice', 'going', 'on'],
#  ['dis', 'is', 'yijue'],
#  ['jus', 'saw', 'ur', 'mail'],
#  ['in', 'case', 'huiming', 'havent', 'sent', 'my', 'num'],
#  ['dis', 'is', 'my', 'num'],
#  ['one', 'small', 'prestige', 'problem', 'now'],
#  ['fancy', 'shag'],
#  ['do', 'interested'],
#  ['sextextuk',
#   'com',
#   'txt',
#   'xxuk',
#   'suzy',
#   'to',
#   'txts',
#   'cost',
#   'per',
#   'msg'],
#  ['tncs', 'on', 'website'],
#  [],
#  ['just', 'checking', 'in', 'on', 'you'],
#  ['really', 'do', 'miss', 'seeing', 'jeremiah'],
#  ['do', 'have', 'great', 'month'],
#  ['nah', 'can', 'help', 'you', 'there', 've', 'never', 'had', 'an', 'iphone'],
#  ['if',
#   'you',
#   're',
#   'not',
#   'in',
#   'my',
#   'car',
#   'in',
#   'an',
#   'hour',
#   'and',
#   'half',
#   'going',
#   'apeshit'],
#  ['today', 'is', 'sorry', 'day'],
#  ['if',
#   'ever',
#   'wa',
#   'angry',
#   'with',
#   'you',
#   'if',
#   'ever',
#   'misbehaved',
#   'or',
#   'hurt',
#   'you'],
#  ['plz',
#   'plz',
#   'just',
#   'slap',
#   'urself',
#   'bcoz',
#   'it',
#   'ur',
#   'fault',
#   'basically',
#   'good'],
#  ['yo',
#   'you',
#   'guy',
#   'ever',
#   'figure',
#   'out',
#   'how',
#   'much',
#   'we',
#   'need',
#   'for',
#   'alcohol'],
#  ['jay',
#   'and',
#   'are',
#   'trying',
#   'to',
#   'figure',
#   'out',
#   'how',
#   'much',
#   'we',
#   'can',
#   'safely',
#   'spend',
#   'on',
#   'weed'],
#  ['lt', 'gt', 'ish', 'minute', 'wa', 'minute', 'ago'],
#  ['wtf'],
#  ['thank',
# ...
#  ['yes', 'think', 'so'],
#  ['am',
#   'in',
#   'office',
#   'but',
#   'my',
#   'lap',
#   'is',
#   'in',
#   'room',
#   'think',
#   'thats',
#   'on',
#   'for',
#   'the',
#   'last',
#   'few',
#   'days'],
#  ['didnt', 'shut', 'that', 'down'],
#  ['pick', 'you', 'up', 'bout', 'ish'],
#  ['what', 'time', 'are', 'and', 'that', 'going'],
#  ['from',
#   'here',
#   'after',
#   'the',
#   'performance',
#   'award',
#   'is',
#   'calculated',
#   'every',
#   'two',
#   'month',
#   'not',
#   'for',
#   'current',
#   'one',
#   'month',
#   'period'],
#  ['wa',
#   'actually',
#   'sleeping',
#   'and',
#   'still',
#   'might',
#   'when',
#   'call',
#   'back'],
#  ['so', 'text', 'is', 'gr'],
#  ['you', 'rock', 'sis'],
#  ['will', 'send', 'text', 'wen', 'wake'],
#  ['you', 'are', 'always', 'putting', 'your', 'business', 'out', 'there'],
#  ['you', 'put', 'picture', 'of', 'your', 'as', 'on', 'facebook'],
#  ['you',
#   'are',
#   'one',
#   'of',
#   'the',
#   'most',
#   'open',
#   'people',
#   've',
#   'ever',
#   'met'],
#  ['why',
#   'would',
#   'think',
#   'picture',
#   'of',
#   'your',
#   'room',
#   'would',
#   'hurt',
#   'you',
#   'make',
#   'you',
#   'feel',
#   'violated'],
#  ['good',
#   'evening',
#   'sir',
#   'al',
#   'salam',
#   'wahleykkum',
#   'sharing',
#   'happy',
#   'news',
#   'by',
#   'the',
#   'grace',
#   'of',
#   'god',
#   'got',
#   'an',
#   'offer',
#   'from',
#   'tayseer',
#   'tissco',
#   'and',
#   'joined',
#   'hope',
#   'you',
#   'are',
#   'fine',
#   'inshah',
#   'allah',
#   'meet',
#   'you',
#   'sometime',
#   'rakhesh',
#   'visitor',
#   'from',
#   'india'],
#  ['hmmm',
#   'but',
#   'want',
#   'to',
#   'change',
#   'the',
#   'field',
#   'quickly',
#   'da',
#   'wanna',
#   'get',
#   'system',
#   'administrator',
#   'or',
#   'network',
#   'administrator'],
#  ['free',
#   'ringtone',
#   'text',
#   'first',
#   'to',
#   'for',
#   'poly',
#   'or',
#   'text',
#   'get',
#   'to',
#   'for',
#   'true',
#   'tone'],
#  ['help'],
#  ['after', 'st', 'free', 'tone', 'are', 'pw', 'to', 'nd', 'txt', 'stop'],
#  ['dear', 'how', 'is', 'chechi'],
#  ['did', 'you', 'talk', 'to', 'her'],
#  ['the', 'hair', 'cream', 'ha', 'not', 'been', 'shipped'],
#  ['none', 'of', 'that', 'happening', 'til', 'you', 'get', 'here', 'though'],
#  ['yep',
#   'the',
#   'great',
#   'loxahatchee',
#   'xmas',
#   'tree',
#   'burning',
#   'of',
#   'lt',
#   'gt',
#   'start',
#   'in',
#   'an',
#   'hour'],
#  ['haha',
#   'get',
#   'used',
#   'to',
#   'driving',
#   'to',
#   'usf',
#   'man',
#   'know',
#   'lot',
#   'of',
#   'stoner'],
#  ['all',
#   'wa',
#   'well',
#   'until',
#   'slightly',
#   'disastrous',
#   'class',
#   'this',
#   'pm',
#   'with',
#   'my',
#   'fav',
#   'darlings'],
#  ['hope',
#   'day',
#   'off',
#   'ok',
#   'coffee',
#   'wld',
#   'be',
#   'good',
#   'can',
#   'stay',
#   'late',
#   'tomorrow'],
#  ['same', 'time', 'place', 'always'],
#  ['hello'],
#  ['good', 'week'],
#  ['fancy', 'drink', 'or', 'something', 'later'],
#  ['headin', 'towards', 'busetop'],
#  ['message',
#   'some',
#   'text',
#   'missing',
#   'sender',
#   'name',
#   'missing',
#   'number',
#   'missing',
#   'sent',
#   'date',
#   'missing',
#   'missing',
#   'lot',
#   'thats',
#   'everything',
#   'is',
#   'missing',
#   'sent',
#   'via',
#   'fullonsms',
#   'com'],
#  ['come',
#   'by',
#   'our',
#   'room',
#   'at',
#   'some',
#   'point',
#   'so',
#   'we',
#   'can',
#   'iron',
#   'out',
#   'the',
#   'plan',
#   'for',
#   'this',
#   'weekend'],
#  ['co', 'want', 'it', 'to', 'be', 'your', 'thing'],
#  ['okies',
#   'll',
#   'go',
#   'yan',
#   'jiu',
#   'too',
#   'we',
#   'can',
#   'skip',
#   'ard',
#   'oso',
#   'go',
#   'cine',
#   'den',
#   'go',
#   'mrt',
#   'one',
#   'blah',
#   'blah',
#   'blah'],
#  ['bring', 'home', 'some', 'wendy'],
#  ['dating', 'service', 'cal', 'box', 'sk', 'ch'],
#  ['whatsup', 'there'],
#  ['dont', 'want', 'to', 'sleep'],
#  ['alright', 'have', 'new', 'goal', 'now'],
#  ['free',
#   'entry',
#   'into',
#   'our',
#   'weekly',
#   'competition',
#   'just',
#   'text',
#   'the',
#   'word',
#   'win',
#   'to',
#   'now'],
#  ['www', 'txttowin', 'co', 'uk'],
#  ['alright',
#   'll',
#   'head',
#   'out',
#   'in',
#   'few',
#   'minutes',
#   'text',
#   'me',
#   'where',
#   'to',
#   'meet',
#   'you'],
#  ['send', 'logo', 'ur', 'lover', 'name', 'joined', 'by', 'heart'],
#  ['txt',
#   'love',
#   'name',
#   'name',
#   'mobno',
#   'eg',
#   'love',
#   'adam',
#   'eve',
#   'to',
#   'yahoo'],
#  ['pobox', 'wq', 'txtno', 'no', 'ad'],
#  ['yes', 'from', 'last', 'week', 'itself', 'taking', 'live', 'call'],
#  ['someone',
#   'ha',
#   'contacted',
#   'our',
#   'dating',
#   'service',
#   'and',
#   'entered',
#   'your',
#   'phone',
#   'because',
#   'they',
#   'fancy',
#   'you'],
#  ['to', 'find', 'out', 'who', 'it', 'is', 'call', 'from', 'landline'],
#  ['pobox', 'tf'],
#  ['siva', 'is', 'in', 'hostel', 'aha'],
#  ['urgent'],
#  ['your',
#   'mobile',
#   'number',
#   'ha',
#   'been',
#   'awarded',
#   'with',
#   'prize',
#   'guaranteed'],
#  ['call', 'from', 'land', 'line'],
#  ['claim', 'valid', 'hrs', 'only'],
#  ['send',
#   'this',
#   'to',
#   'ur',
#   'friend',
#   'and',
#   'receive',
#   'something',
#   'about',
#   'ur',
#   'voice',
#   'how',
#   'is',
#   'my',
#   'speaking',
#   'expression'],
#  ['childish',
#   'naughty',
#   'sentiment',
#   'rowdy',
#   'ful',
#   'of',
#   'attitude',
#   'romantic',
#   'shy',
#   'attractive',
#   'funny',
#   'lt',
#   'gt',
#   'irritating',
#   'lt',
#   'gt',
#   'lovable'],
#  ['reply', 'me'],
#  ['ok', 'she', 'll', 'be', 'ok', 'guess'],
#  ['aathi', 'where', 'are', 'you', 'dear'],
#  ['any', 'pain', 'on', 'urination', 'any', 'thing', 'else'],
#  ['at',
#   'esplanade',
#   'do',
#   'mind',
#   'giving',
#   'me',
#   'lift',
#   'co',
#   'got',
#   'no',
#   'car',
#   'today'],
#  ['wnt',
#   'to',
#   'buy',
#   'bmw',
#   'car',
#   'urgently',
#   'its',
#   'vry',
#   'urgent',
#   'but',
#   'hv',
#   'shortage',
#   'of',
#   'lt',
#   'gt',
#   'lacs',
#   'there',
#   'is',
#   'no',
#   'source',
#   'to',
#   'arng',
#   'dis',
#   'amt'],
#  ['lt', 'gt', 'lacs', 'thats', 'my', 'prob'],
#  ['at', 'home', 'watching', 'tv', 'lor'],
#  ['doe',
#   'she',
#   'usually',
#   'take',
#   'fifteen',
#   'fucking',
#   'minute',
#   'to',
#   'respond',
#   'to',
#   'yes',
#   'or',
#   'no',
#   'question'],
#  ['congrats'],
#  ['nokia',
#   'video',
#   'camera',
#   'phone',
#   'is',
#   'your',
#   'call',
#   'call',
#   'cost',
#   'ppm',
#   'ave',
#   'call',
#   'mins',
#   'vary',
#   'from',
#   'mobile',
#   'close',
#   'post',
#   'bcm',
#   'ldn',
#   'wc',
#   'xx'],
#  ['booked', 'ticket', 'for', 'pongal'],
#  ['you', 'available', 'now'],
#  ['like', 'right', 'around', 'hillsborough', 'amp', 'lt', 'gt', 'th'],
#  ['the', 'message', 'sent', 'is', 'askin', 'for', 'lt', 'gt', 'dollars'],
#  ['shoul', 'pay', 'lt', 'gt', 'or', 'lt', 'gt'],
#  ['ask',
#   'or',
#   'iouri',
#   've',
#   'told',
#   'the',
#   'story',
#   'like',
#   'ten',
#   'time',
#   'already'],
#  ['how', 'long', 'doe', 'applebees', 'fucking', 'take'],
#  ['hi',
#   'hope',
#   'get',
#   'this',
#   'txt',
#   'journey',
#   'hasnt',
#   'been',
#   'gd',
#   'now',
#   'about',
#   'min',
#   'late',
#   'think'],
#  ['but', 'have', 'to'],
#  ['like', 'to', 'have', 'love', 'and', 'arrange'],
#  ['yes',
#   'he',
#   'is',
#   'really',
#   'great',
#   'bhaji',
#   'told',
#   'kallis',
#   'best',
#   'cricketer',
#   'after',
#   'sachin',
#   'in',
#   'world',
#   'very',
#   'tough',
#   'to',
#   'get',
#   'out'],
#  ['you', 'were', 'supposed', 'to', 'wake', 'me', 'up', 'gt'],
#  ['oic',
#   'saw',
#   'him',
#   'too',
#   'but',
#   'tot',
#   'he',
#   'din',
#   'me',
#   'found',
#   'group',
#   'liao'],
#  ['sorry', 'll', 'call', 'later'],
#  ['hey', 'hey', 'werethe', 'monkeespeople', 'say', 'we', 'monkeyaround'],
#  ['howdy', 'gorgeous', 'howu', 'doin'],
#  ['foundurself', 'jobyet', 'sausage', 'love', 'jen', 'xxx'],
#  ['sorry',
#   'my',
#   'battery',
#   'died',
#   'can',
#   'come',
#   'by',
#   'but',
#   'only',
#   'getting',
#   'gram',
#   'for',
#   'now',
#   'where',
#   'your',
#   'place'],
#  ['well',
#   'done',
#   'blimey',
#   'exercise',
#   'yeah',
#   'kinda',
#   'remember',
#   'wot',
#   'that',
#   'is',
#   'hmm'],
#  ['wont',
#   'get',
#   'concentration',
#   'dear',
#   'you',
#   'know',
#   'you',
#   'are',
#   'my',
#   'mind',
#   'and',
#   'everything'],
#  ['lol', 'have', 'you', 'made', 'plan', 'for', 'new', 'years'],
#  ['min', 'later'],
#  ['hank', 'lotsly'],
#  ['thanks', 'for', 'this', 'hope', 'you', 'had', 'good', 'day', 'today'],
#  ['what',
#   'are',
#   'detail',
#   'you',
#   'want',
#   'to',
#   'transfer',
#   'acc',
#   'no',
#   'enough'],
#  ['ok', 'will', 'tell', 'her', 'to', 'stay', 'out'],
#  ['yeah',
#   'it',
#   'been',
#   'tough',
#   'but',
#   'we',
#   'are',
#   'optimistic',
#   'thing',
#   'will',
#   'improve',
#   'this',
#   'month'],
#  ['loan', 'for', 'any', 'purpose'],
#  ['homeowner', 'tenant', 'welcome'],
#  ['have', 'you', 'been', 'previously', 'refused'],
#  ['we', 'can', 'still', 'help'],
#  ['call', 'free', 'or', 'text', 'back', 'help'],
#  ['si', 'si'],
#  ['think', 'ill', 'go', 'make', 'those', 'oreo', 'truffles'],
#  ['look',
#   'at',
#   'amy',
#   'ure',
#   'beautiful',
#   'intelligent',
#   'woman',
#   'and',
#   'like',
#   'lot'],
#  ['know', 'don', 'like', 'me', 'like', 'that', 'so', 'don', 'worry'],
#  ['hope',
#   'you',
#   'that',
#   'the',
#   'result',
#   'of',
#   'being',
#   'consistently',
#   'intelligent',
#   'and',
#   'kind'],
#  ['start',
#   'asking',
#   'him',
#   'about',
#   'practicum',
#   'link',
#   'and',
#   'keep',
#   'your',
#   'ear',
#   'open',
#   'and',
#   'all',
#   'the',
#   'best'],
#  ['ttyl'],
#  ['that', 'call', 'cost'],
#  ['which', 'guess', 'isnt', 'bad'],
#  ['miss', 'ya', 'need', 'ya', 'want', 'ya', 'love', 'ya'],
#  ['going',
#   'thru',
#   'very',
#   'different',
#   'feeling',
#   'wavering',
#   'decision',
#   'and',
#   'coping',
#   'up',
#   'with',
#   'the',
#   'same',
#   'is',
#   'the',
#   'same',
#   'individual',
#   'time',
#   'will',
#   'heal',
#   'everything',
#   'believe'],
#  ['where', 'did', 'go'],
#  ['my',
#   'phone',
#   'is',
#   'gonna',
#   'die',
#   'you',
#   'have',
#   'to',
#   'stay',
#   'in',
#   'here'],
#  ['great'],
#  ['never', 'been', 'better'],
#  ['each', 'day', 'give', 'even', 'more', 'reason', 'to', 'thank', 'god'],
#  ['upgrdcentre',
#   'orange',
#   'customer',
#   'you',
#   'may',
#   'now',
#   'claim',
#   'your',
#   'free',
#   'camera',
#   'phone',
#   'upgrade',
#   'for',
#   'your',
#   'loyalty'],
#  ['call', 'now', 'on', 'offer', 'end', 'th', 'july'],
#  ['apply'],
#  ['opt', 'out', 'available'],
#  ['sorry', 'll', 'call', 'later', 'ok', 'bye'],
#  ['ok', 'am', 'on', 'the', 'way', 'to', 'railway'],
#  ['great', 'princess'],
#  ['love', 'giving', 'and', 'receiving', 'oral'],
#  ['doggy', 'style', 'is', 'my', 'fave', 'position'],
#  ['how', 'about', 'you'],
#  ['enjoy', 'making', 'love', 'lt', 'gt', 'time', 'per', 'night'],
#  ['they',
#   'don',
#   'put',
#   'that',
#   'stuff',
#   'on',
#   'the',
#   'road',
#   'to',
#   'keep',
#   'it',
#   'from',
#   'getting',
#   'slippery',
#   'over',
#   'there'],
#  ['when', 'are', 'you', 'going', 'to', 'ride', 'your', 'bike'],
#  ['yup', 'no', 'need'],
#  ['ll', 'jus', 'wait', 'rain', 'stop'],
#  ['there', 'are', 'many', 'company'],
#  ['tell', 'me', 'the', 'language'],
#  ['okmail',
#   'dear',
#   'dave',
#   'this',
#   'is',
#   'your',
#   'final',
#   'notice',
#   'to',
#   'collect',
#   'your',
#   'tenerife',
#   'holiday',
#   'or',
#   'cash',
#   'award'],
#  ['call', 'from', 'landline'],
#  ['tc', 'sae', 'box', 'cw', 'wx', 'ppm'],
#  ['how', 'long', 'ha', 'it', 'been', 'since', 'you', 'screamed', 'princess'],
#  ['nothing'],
#  ['meant',
#   'that',
#   'once',
#   'the',
#   'money',
#   'enters',
#   'your',
#   'account',
#   'here',
#   'the',
#   'bank',
#   'will',
#   'remove',
#   'it',
#   'flat',
#   'rate'],
#  ['someone',
#   'transfered',
#   'lt',
#   'gt',
#   'to',
#   'my',
#   'account',
#   'and',
#   'lt',
#   'gt',
#   'dollar',
#   'got',
#   'removed'],
#  ['so',
#   'the',
#   'bank',
#   'differ',
#   'and',
#   'charge',
#   'also',
#   'differ',
#   'be',
#   'sure',
#   'you',
#   'trust',
#   'the',
#   'ja',
#   'person',
#   'you',
#   'are',
#   'sending',
#   'account',
#   'detail',
#   'to',
#   'cos'],
#  ['want', 'get', 'laid', 'tonight'],
#  ['want', 'real', 'dogging', 'location', 'sent', 'direct', 'ur', 'mob'],
#  ['join',
#   'the',
#   'uk',
#   'largest',
#   'dogging',
#   'network',
#   'by',
#   'txting',
#   'moan',
#   'to',
#   'nyt'],
#  ['ec'],
#  ['msg'],
#  ['nice',
#   'line',
#   'said',
#   'by',
#   'broken',
#   'heart',
#   'plz',
#   'don',
#   'cum',
#   'more',
#   'time',
#   'infront',
#   'of',
#   'me',
#   'other',
#   'wise',
#   'once',
#   'again',
#   'll',
#   'trust',
#   'good'],
#  ['ok', 'gonna', 'head', 'up', 'to', 'usf', 'in', 'like', 'fifteen', 'minute'],
#  ['love', 'you', 'aathi', 'love', 'lot'],
#  ['tension', 'ah', 'what', 'machi', 'any', 'problem'],
#  ['can', 'pick', 'up', 'another', 'th', 'when', 'you', 're', 'done'],
#  ['when', 're', 'you', 'guy', 'getting', 'back'],
#  ['said', 'you', 'were', 'thinking', 'about', 'not', 'staying', 'for', 'mcr'],
#  ['almost', 'there', 'see', 'in', 'sec'],
#  ['yo',
#   'carlos',
#   'few',
#   'friend',
#   'are',
#   'already',
#   'asking',
#   'me',
#   'about',
#   'you',
#   'you',
#   'working',
#   'at',
#   'all',
#   'this',
#   'weekend'],
#  ['watching', 'tv', 'lor'],
#  ['thank', 'you', 'baby'],
#  ['cant', 'wait', 'to', 'taste', 'the', 'real', 'thing'],
#  ['you',
#   'should',
#   'change',
#   'your',
#   'fb',
#   'to',
#   'jaykwon',
#   'thuglyfe',
#   'falconerf'],
#  ['if', 'we', 'win', 'it', 'really', 'no', 'side', 'for', 'long', 'time'],
#  ['free',
#   'message',
#   'activate',
#   'your',
#   'free',
#   'text',
#   'message',
#   'by',
#   'replying',
#   'to',
#   'this',
#   'message',
#   'with',
#   'the',
#   'word',
#   'free',
#   'for',
#   'term',
#   'conditions',
#   'visit',
#   'www',
#   'com'],
#  ['dear', 'reached', 'railway'],
#  ['what', 'happen', 'to', 'you'],
#  ['depends', 'on', 'quality'],
#  ['if',
#   'you',
#   'want',
#   'the',
#   'type',
#   'sent',
#   'boye',
#   'faded',
#   'glory',
#   'then',
#   'about',
#   'if',
#   'you',
#   'want',
#   'ralphs',
#   'maybe'],
#  ['think', 've', 'fixed', 'it', 'can', 'you', 'send', 'test', 'message'],
#  ['sorry',
#   'man',
#   'my',
#   'account',
#   'dry',
#   'or',
#   'would',
#   'if',
#   'you',
#   'want',
#   'we',
#   'could',
#   'trade',
#   'back',
#   'half',
#   'or',
#   'could',
#   'buy',
#   'some',
#   'shit',
#   'with',
#   'my',
#   'credit',
#   'card'],
#  ['congrats'],
#  ['year', 'special', 'cinema', 'pas', 'for', 'is', 'yours'],
#  ['call', 'now'],
#  ['suprman', 'matrix', 'starwars', 'etc', 'all', 'free'],
#  ['bx', 'ip', 'we'],
#  ['pm'],
#  ['dont', 'miss', 'out'],
#  ['sorry', 'in', 'meeting', 'll', 'call', 'later'],
#  ['what', 'class', 'of', 'lt', 'gt', 'reunion'],
#  ['are', 'you', 'free', 'now', 'can', 'call', 'now'],
#  ['got', 'meh', 'when'],
#  ['nope',
#   'think',
#   'will',
#   'go',
#   'for',
#   'it',
#   'on',
#   'monday',
#   'sorry',
#   'replied',
#   'so',
#   'late'],
#  ['some', 'of', 'them', 'told', 'accenture', 'is', 'not', 'confirm'],
#  ['is', 'it', 'true'],
#  ['kate', 'jackson', 'rec', 'center', 'before', 'ish', 'right'],
#  ['dear', 'have', 'reache', 'room'],
#  ['fighting',
#   'with',
#   'the',
#   'world',
#   'is',
#   'easy',
#   'either',
#   'win',
#   'or',
#   'lose',
#   'bt',
#   'fightng',
#   'with',
#   'some',
#   'who',
#   'is',
#   'close',
#   'to',
#   'is',
#   'dificult',
#   'if',
#   'lose',
#   'lose',
#   'if',
#   'win',
#   'still',
#   'lose'],
#  ['when', 'can', 'come', 'out'],
#  ['check', 'with', 'nuerologist'],
#  ['lolnice'],
#  ['went', 'from', 'fish', 'to', 'water'],
#  [],
#  ['congratulation',
#   'in',
#   'this',
#   'week',
#   'competition',
#   'draw',
#   'have',
#   'won',
#   'the',
#   'prize',
#   'to',
#   'claim',
#   'just',
#   'call'],
#  ['cs', 'stop', 'sm', 'over', 'only', 'ppm'],
#  ['no', 'it', 'waiting', 'in', 'car', 'dat', 'bored', 'wat'],
#  ['co', 'wait', 'outside', 'got', 'nothing', 'do'],
#  ['at', 'home', 'can', 'do', 'my', 'stuff', 'or', 'watch', 'tv', 'wat'],
#  ['maybe',
#   'westshore',
#   'or',
#   'hyde',
#   'park',
#   'village',
#   'the',
#   'place',
#   'near',
#   'my',
#   'house'],
#  ['you', 'should', 'know', 'now'],
#  ['so', 'how', 'anthony'],
#  ['are', 'you', 'bringing', 'money'],
#  ['ve',
#   'school',
#   'fee',
#   'to',
#   'pay',
#   'and',
#   'rent',
#   'and',
#   'stuff',
#   'like',
#   'that'],
#  ['thats', 'why', 'need', 'your', 'help'],
#  ['friend', 'in', 'need'],
#  ['what', 'the', 'significance'],
#  ['your', 'opinion', 'about', 'me'],
#  ['over',
#   'jada',
#   'kusruthi',
#   'lovable',
#   'silent',
#   'spl',
#   'character',
#   'not',
#   'matured',
#   'stylish',
#   'simple',
#   'pls',
#   'reply'],
#  ['at',
#   'the',
#   'latest',
#   'still',
#   'there',
#   'if',
#   'you',
#   'can',
#   'scrounge',
#   'up',
#   'some',
#   'ammo',
#   'and',
#   'want',
#   'to',
#   'give',
#   'the',
#   'new',
#   'ak',
#   'try'],
#  ['prabha', 'soryda', 'realy', 'frm', 'heart', 'sory'],
#  ['lol', 'ok', 'your', 'forgiven'],
#  ['no', 'jst', 'change', 'tat', 'only'],
#  ['you',
#   'are',
#   'guaranteed',
#   'the',
#   'latest',
#   'nokia',
#   'phone',
#   'gb',
#   'ipod',
#   'mp',
#   'player',
#   'or',
#   'prize'],
#  ['txt', 'word', 'collect', 'to', 'no'],
#  ...]

# %%
import gensim

# %%
#Let's try Word2Vec from scratch
model = gensim.models.Word2Vec(sentences = words)

# %%
model.wv.index_to_key
# Out:
# ['to',
#  'you',
#  'the',
#  'and',
#  'it',
#  'in',
#  'is',
#  'me',
#  'my',
#  'for',
#  'your',
#  'call',
#  'of',
#  'that',
#  'have',
#  'on',
#  'now',
#  'are',
#  'can',
#  'so',
#  'but',
#  'not',
#  'or',
#  'we',
#  'do',
#  'get',
#  'at',
#  'ur',
#  'if',
#  'will',
#  'be',
#  'with',
#  'no',
#  'just',
#  'this',
#  'gt',
#  'lt',
#  'go',
#  'how',
#  'up',
#  'when',
#  'ok',
#  'what',
#  'free',
#  'from',
#  'all',
#  'out',
#  'know',
#  'day',
#  'll',
#  'like',
#  'come',
#  'good',
#  'am',
#  'then',
#  'got',
#  'time',
#  'wa',
#  'there',
#  'he',
#  'love',
#  'only',
#  'want',
#  'text',
#  'send',
#  'need',
#  'txt',
#  'one',
#  'today',
#  'by',
#  'going',
#  'don',
#  'she',
#  'home',
#  'stop',
#  'about',
#  'lor',
#  'sorry',
#  'see',
#  'still',
#  'take',
#  'mobile',
#  'back',
#  'da',
#  'dont',
#  'our',
#  'reply',
#  'think',
#  'tell',
#  'hi',
#  'phone',
#  'week',
#  'new',
#  'they',
#  'later',
#  'please',
#  'any',
#  'pls',
#  'her',
#  'did',
#  'ha',
#  'co',
#  'been',
#  'some',
#  'dear',
#  'make',
#  'who',
#  'msg',
#  'an',
#  'here',
#  'well',
#  'say',
#  'night',
#  'where',
#  're',
#  'much',
#  'hope',
#  'oh',
#  'claim',
#  'great',
#  'hey',
#  'him',
#  'message',
#  'more',
#  'give',
#  'too',
#  'number',
#  'happy',
#  'wat',
#  'thing',
#  'work',
#  'min',
#  'had',
#  'way',
#  'yes',
#  'www',
#  've',
#  'should',
#  'let',
#  'won',
#  'prize',
#  'right',
#  'tomorrow',
#  'already',
#  'after',
#  'friend',
#  'said',
#  'ask',
#  'doing',
#  'amp',
#  'cash',
#  'win',
#  'im',
#  'yeah',
#  'really',
#  'life',
#  'why',
#  'meet',
#  'tone',
#  'babe',
#  'find',
#  'them',
#  'miss',
#  'very',
#  'morning',
#  'last',
#  'uk',
#  'thanks',
#  'care',
#  'would',
#  'anything',
#  'com',
#  'also',
#  'service',
#  'nokia',
#  'lol',
#  'every',
#  'feel',
#  'keep',
#  'pick',
#  'sure',
#  'sent',
#  'contact',
#  'year',
#  'urgent',
#  'over',
#  'something',
#  'gud',
#  'buy',
#  'again',
#  'before',
#  'cant',
#  'wait',
#  'box',
#  'first',
#  'place',
#  'his',
#  'even',
#  'someone',
#  'help',
#  'went',
#  'wish',
#  'nice',
#  'were',
#  'next',
#  'tonight',
#  'off',
#  'which',
#  'soon',
#  'around',
#  'show',
#  'money',
#  'could',
#  'customer',
#  'many',
#  'sleep',
#  'guy',
#  'chat',
#  'late',
#  'per',
#  'ya',
#  'always',
#  'gonna',
#  'wan',
#  'leave',
#  'down',
#  'name',
#  'other',
#  'lot',
#  'pm',
#  'dun',
#  'told',
#  'st',
#  'waiting',
#  'special',
#  'hello',
#  'word',
#  'person',
#  'try',
#  'fine',
#  'may',
#  'coming',
#  'haha',
#  'people',
#  'end',
#  'best',
#  'th',
#  'thk',
#  'yet',
#  'guaranteed',
#  'same',
#  'girl',
#  'done',
#  'getting',
#  'heart',
#  'god',
#  'ppm',
#  'use',
#  'thought',
#  'didn',
#  'start',
#  'minute',
#  'holiday',
#  'hour',
#  'line',
#  'offer',
#  'smile',
#  'class',
#  'bit',
#  'man',
#  'live',
#  'lunch',
#  'stuff',
#  'talk',
#  'month',
#  'few',
#  'mean',
#  'job',
#  'finish',
#  'cost',
#  'draw',
#  'never',
#  'being',
#  'car',
#  'ill',
#  'house',
#  'better',
#  'cool',
#  'thats',
#  'meeting',
#  'trying',
#  'yup',
#  'mind',
#  'having',
#  'problem',
#  'ready',
#  'dat',
#  'account',
#  'long',
#  'pobox',
#  'rate',
#  'chance',
#  'enjoy',
#  'plan',
#  'wk',
#  'real',
#  'half',
#  'weekend',
#  'latest',
#  'world',
#  'than',
#  'because',
#  'sir',
#  'bt',
#  'guess',
#  'yo',
#  'check',
#  'play',
#  'room',
#  'luv',
#  'nothing',
#  'po',
#  'wanna',
#  'awarded',
#  'sweet',
#  'look',
#  'eat',
#  'camera',
#  'receive',
#  'lar',
#  'shit',
#  'big',
#  'liao',
#  'another',
#  'into',
#  'birthday',
#  'ah',
#  'dinner',
#  'xxx',
#  'quite',
#  'ever',
#  'cs',
#  'might',
#  'video',
#  'voucher',
#  'jus',
#  'boy',
#  'pic',
#  'watch',
#  'landline',
#  'watching',
#  'wont',
#  'probably',
#  'orange',
#  'two',
#  'thanx',
#  'called',
#  'tv',
#  'aight',
#  'bed',
#  'pa',
#  'once',
#  'hear',
#  'sm',
#  'nd',
#  'speak',
#  'fun',
#  'early',
#  'kiss',
#  'princess',
#  'bad',
#  'den',
#  'actually',
#  'sat',
#  'shall',
#  'baby',
#  'nite',
#  'age',
#  'forgot',
#  'maybe',
#  'ringtone',
#  'left',
#  'bus',
#  'pay',
#  'remember',
#  'apply',
#  'office',
#  'dunno',
#  'made',
#  'shopping',
#  'reach',
#  'easy',
#  'between',
#  'part',
#  'code',
#  'network',
#  'dad',
#  'fuck',
#  'put',
#  'true',
#  'didnt',
#  'everything',
#  'face',
#  'leh',
#  'evening',
#  'little',
#  'award',
#  'anyway',
#  'hrs',
#  'worry',
#  'hurt',
#  'xx',
#  'dis',
#  'doe',
#  'town',
#  'game',
#  'wife',
#  'working',
#  'those',
#  'looking',
#  'thank',
#  'enough',
#  'selected',
#  'question',
#  'while',
#  'gift',
#  'asked',
#  'collect',
#  'sound',
#  'tmr',
#  'missing',
#  'without',
#  'mail',
#  'school',
#  'afternoon',
#  'most',
#  'pound',
#  'entry',
#  'important',
#  'hav',
#  'xmas',
#  'sexy',
#  'join',
#  'must',
#  'price',
#  'okay',
#  'movie',
#  'came',
#  'pain',
#  'since',
#  'wanted',
#  'valid',
#  'though',
#  'wif',
#  'until',
#  'collection',
#  'bring',
#  'wot',
#  'wake',
#  'able',
#  'til',
#  'abt',
#  'mob',
#  'run',
#  'missed',
#  'plus',
#  'away',
#  'de',
#  'change',
#  'plz',
#  'charge',
#  'decimal',
#  'stay',
#  'answer',
#  'juz',
#  'haven',
#  'wen',
#  'sms',
#  'date',
#  'attempt',
#  'bored',
#  'dude',
#  'weekly',
#  'book',
#  'mins',
#  'music',
#  'shop',
#  'else',
#  'havent',
#  'hair',
#  'double',
#  'yesterday',
#  'saw',
#  'till',
#  'alright',
#  'colour',
#  'update',
#  'lei',
#  'goin',
#  'online',
#  'these',
#  'drink',
#  'friendship',
#  'optout',
#  'oso',
#  'id',
#  'coz',
#  'haf',
#  'top',
#  'food',
#  'making',
#  'yours',
#  'net',
#  'family',
#  'sch',
#  'either',
#  'feeling',
#  'detail',
#  'club',
#  'hot',
#  'gr',
#  'yr',
#  'player',
#  'address',
#  'test',
#  'driving',
#  'yourself',
#  'delivery',
#  'tried',
#  'ard',
#  'national',
#  'sad',
#  'mate',
#  'together',
#  'lose',
#  'sae',
#  'beautiful',
#  'tot',
#  'head',
#  'calling',
#  'full',
#  'wid',
#  'walk',
#  'both',
#  'story',
#  'believe',
#  'order',
#  'dream',
#  'nt',
#  'busy',
#  'trip',
#  'bonus',
#  'lesson',
#  'http',
#  'days',
#  'brother',
#  'await',
#  'drive',
#  'saying',
#  'mum',
#  'eve',
#  'poly',
#  'huh',
#  'chikku',
#  'row',
#  'post',
#  'ring',
#  'happen',
#  'noe',
#  'sleeping',
#  'si',
#  'smoke',
#  'leaving',
#  'old',
#  'smiling',
#  'second',
#  'info',
#  'set',
#  'drop',
#  'rite',
#  'email',
#  'pub',
#  'simple',
#  'thinking',
#  'its',
#  'land',
#  'suite',
#  'mths',
#  'okie',
#  'wil',
#  'awesome',
#  'private',
#  'cause',
#  'close',
#  'started',
#  'finished',
#  'took',
#  'congrats',
#  'tomo',
#  'doesn',
#  'aft',
#  'news',
#  'hl',
#  'auction',
#  'anyone',
#  'neva',
#  'mine',
#  'gd',
#  'reason',
#  'sister',
#  'card',
#  'unsubscribe',
#  'angry',
#  'company',
#  'break',
#  'touch',
#  'content',
#  'everyone',
#  'taking',
#  'statement',
#  'forget',
#  'mom',
#  'tho',
#  'credit',
#  'final',
#  'available',
#  'alone',
#  'loving',
#  'knw',
#  'sun',
#  'whatever',
#  'opt',
#  'dating',
#  'valentine',
#  'friends',
#  'choose',
#  'found',
#  'worth',
#  'carlos',
#  'bank',
#  'fancy',
#  'each',
#  'hand',
#  'whats',
#  'open',
#  'type',
#  'match',
#  'expires',
#  'search',
#  'lucky',
#  'treat',
#  'point',
#  'hows',
#  'fast',
#  'visit',
#  'nyt',
#  'kind',
#  'bout',
#  'mobileupd',
#  'far',
#  'anytime',
#  'gbp',
#  'tc',
#  'college',
#  'boytoy',
#  'frnd',
#  'hard',
#  'ltd',
#  'ni',
#  'quiz',
#  'identifier',
#  'points',
#  'uncle',
#  'friday',
#  'happened',
#  'hit',
#  'gone',
#  'prob',
#  'ticket',
#  'song',
#  'decided',
#  'saturday',
#  'smth',
#  'wonderful',
#  'winner',
#  'chennai',
#  'party',
#  'least',
#  'wrong',
#  'lovely',
#  'wonder',
#  'gal',
#  'sea',
#  'pretty',
#  'fri',
#  'outside',
#  'nope',
#  'fucking',
#  'lands',
#  'light',
#  'read',
#  'hold',
#  'tel',
#  'secret',
#  'exam',
#  'oredi',
#  'goodmorning',
#  'darlin',
#  'mrng',
#  'finally',
#  'wit',
#  'mu',
#  'operator',
#  'used',
#  'camcorder',
#  'crazy',
#  'wasn',
#  'support',
#  'earlier',
#  'drug',
#  'snow',
#  'listen',
#  'sub',
#  'savamob',
#  'frm',
#  'cum',
#  'welcome',
#  'ten',
#  'project',
#  'jay',
#  'as',
#  'fone',
#  'blue',
#  'unlimited',
#  'cd',
#  'congratulation',
#  'fr',
#  'meant',
#  'case',
#  'course',
#  'log',
#  'their',
#  'hmm',
#  'isn',
#  'frnds',
#  'whole',
#  'telling',
#  'calls',
#  'seeing',
#  'hungry',
#  'wq',
#  'sunday',
#  'freemsg',
#  'wkly',
#  'father',
#  'gas',
#  'john',
#  'hr',
#  'enter',
#  'luck',
#  'na',
#  'gn',
#  'knew',
#  'understand',
#  'store',
#  'mayb',
#  'sell',
#  'sex',
#  'paper',
#  'area',
#  'happiness',
#  'yar',
#  'un',
#  'within',
#  'park',
#  'term',
#  'sk',
#  'india',
#  'couple',
#  'talking',
#  'motorola',
#  'moment',
#  'currently',
#  'ago',
#  'txts',
#  'reading',
#  'christmas',
#  'lost',
#  'bslvyl',
#  'die',
#  'stupid',
#  'single',
#  'dnt',
#  'side',
#  'march',
#  'balance',
#  'mr',
#  'hmmm',
#  'joy',
#  'us',
#  'tired',
#  'caller',
#  'invited',
#  'felt',
#  'mah',
#  'download',
#  'hee',
#  'cut',
#  'move',
#  'etc',
#  'almost',
#  'eh',
#  'valued',
#  'press',
#  'parent',
#  'dreams',
#  'difficult',
#  'film',
#  'grins',
#  'surprise',
#  'information',
#  'heard',
#  'sort',
#  'extra',
#  'ugh',
#  'picking',
#  'xy',
#  'darren',
#  'gym',
#  'through',
#  'max',
#  'redeemed',
#  'ipod',
#  'doin',
#  'supposed',
#  'rock',
#  'rental',
#  'seen',
#  'met',
#  'ish',
#  'via',
#  'return',
#  'games',
#  'ge',
#  'swing',
#  'laptop',
#  'reveal',
#  'bcoz',
#  'semester',
#  'bill',
#  'direct',
#  'sending',
#  'askd',
#  'computer',
#  'shower',
#  'load',
#  'gotta',
#  'complimentary',
#  'pas',
#  'correct',
#  'red',
#  'ac',
#  'wow',
#  'hospital',
#  'confirm',
#  'charged',
#  'promise',
#  'comp',
#  'police',
#  'slowly',
#  'loved',
#  'fact',
#  'nobody',
#  'truth',
#  'photo',
#  'asap',
#  'whenever',
#  'ts',
#  'noon',
#  'train',
#  'door',
#  'clean',
#  'blood',
#  'member',
#  'monday',
#  'remove',
#  'asking',
#  'yep',
#  'slow',
#  'discount',
#  'hg',
#  'ex',
#  'weed',
#  'small',
#  'pete',
#  'rest',
#  'somebody',
#  'hmv',
#  'leaf',
#  'wana',
#  'own',
#  'study',
#  'kate',
#  'orchard',
#  'bath',
#  'muz',
#  'safe',
#  'wine',
#  'lovable',
#  'txting',
#  'dogging',
#  'entered',
#  'things',
#  'loan',
#  'save',
#  'rply',
#  'checking',
#  'messages',
#  'crave',
#  'abiola',
#  'comin',
#  'eg',
#  'link',
#  'wap',
#  'reward',
#  'usf',
#  'std',
#  'empty',
#  'med',
#  'eye',
#  'hw',
#  'write',
#  'fantasy',
#  'bb',
#  'ringtones',
#  'rs',
#  'energy',
#  'convey',
#  'rd',
#  'cr',
#  'ntt',
#  'otherwise',
#  'poor',
#  'gettin',
#  'getzed',
#  'summer',
#  'wishing',
#  'glad',
#  'fantastic',
#  'gap',
#  'king',
#  'laugh',
#  'ho',
#  'em',
#  'kid',
#  'cheap',
#  'warm',
#  'across',
#  'hoping',
#  'lady',
#  'less',
#  'near',
#  'water',
#  'different',
#  'booked',
#  'wc',
#  'ldn',
#  'voice',
#  'mm',
#  'woke',
#  'rakhesh',
#  'figure',
#  'custcare',
#  'immediately',
#  'merry',
#  'normal',
#  'somewhere',
#  'tonite',
#  'usual',
#  'lover',
#  'deep',
#  'admirer',
#  'kick',
#  'street',
#  'teach',
#  'deal',
#  'bathe',
#  'spend',
#  'pray',
#  'sony',
#  'del',
#  'men',
#  'gave',
#  'representative',
#  'il',
#  'forever',
#  'reached',
#  'oops',
#  'child',
#  'catch',
#  ...]

# %%
model.corpus_count
# Out:
# 10705

# %%
model.epochs
# Out:
# 5

# %%
model.wv.similar_by_word('good')
# Out:
# [('night', 0.9988241791725159),
#  ('day', 0.9986836910247803),
#  ('all', 0.9986634254455566),
#  ('great', 0.9986499547958374),
#  ('dear', 0.9986345767974854),
#  ('happy', 0.9986184239387512),
#  ('nice', 0.99851393699646),
#  ('my', 0.9984873533248901),
#  ('amp', 0.9984184503555298),
#  ('last', 0.9983805418014526)]

# %%
model.wv['good'].shape
# Out:
# (100,)

# %%
words[0]
# Out:
# ['go',
#  'until',
#  'jurong',
#  'point',
#  'crazy',
#  'available',
#  'only',
#  'in',
#  'bugis',
#  'great',
#  'world',
#  'la',
#  'buffet',
#  'cine',
#  'there',
#  'got',
#  'amore',
#  'wat']

# %%
import numpy as np
def avg_word2vec(doc):
    vectors = [model.wv[word] for word in doc if word in model.wv.index_to_key]
    
    if len(vectors) == 0:
        return np.zeros(model.vector_size)   # FIX ✅
    
    return np.mean(vectors, axis=0)

# %%
X = [avg_word2vec(doc) for doc in words]
X_new = np.array(X)

# %%
# !pip install tqdm
# Out:
# Requirement already satisfied: tqdm in c:\users\rkroh\anaconda3\lib\site-packages (4.67.1)
# Requirement already satisfied: colorama in c:\users\rkroh\anaconda3\lib\site-packages (from tqdm) (0.4.6)

# %%
from tqdm import tqdm

# %%
#apply for the entire sentences
import numpy as np
X=[]
for i in tqdm(range(len(words))):
    X.append(avg_word2vec(words[i]))
# Out:
# 100%|██████████| 10705/10705 [00:01<00:00, 5421.11it/s]

# %%
len(X)
# Out:
# 10705

# %%
##independent Features
X_new=np.array(X)
print(len(X_new))
# Out:
# 10705

# %%
messages.shape
# Out:
# (5572, 2)

# %%
X[1]
# Out:
# array([-1.05518222e-01,  2.94397414e-01,  6.25917464e-02,  9.88197178e-02,
#         3.88806313e-02, -4.27687883e-01,  8.53658319e-02,  5.29841483e-01,
#        -1.88879445e-01, -2.05626398e-01, -9.99899358e-02, -2.94342428e-01,
#         9.43996757e-03,  4.49590012e-02,  1.47568554e-01, -1.65560097e-01,
#         1.08884878e-01, -2.48104513e-01,  4.69012707e-02, -4.18464243e-01,
#         7.41878077e-02,  8.51427913e-02,  8.66038799e-02, -2.21720099e-01,
#        -1.16665378e-01,  3.99821857e-03, -2.95759052e-01, -1.12203896e-01,
#        -1.84554741e-01,  4.05527622e-04,  2.60619760e-01,  4.27285731e-02,
#         9.05774534e-02, -1.72239050e-01, -1.48689210e-01,  3.08006287e-01,
#         7.09239859e-04, -1.17982671e-01, -1.27600566e-01, -3.87085915e-01,
#         8.22755098e-02, -2.27530912e-01, -1.74951643e-01,  1.15315234e-02,
#         1.65422723e-01, -4.35851216e-02, -1.59190089e-01, -6.68320283e-02,
#         5.40079847e-02,  1.19637519e-01,  9.33694020e-02, -2.23955035e-01,
#        -1.95194911e-02,  1.44559974e-02, -6.34151548e-02,  1.41412705e-01,
#         1.00409910e-01, -2.57245526e-02, -2.07223803e-01,  1.50520742e-01,
#         3.54954302e-02,  3.14367302e-02,  7.14098960e-02, -5.71601093e-02,
#        -2.44589329e-01,  1.94510609e-01,  7.63746649e-02,  1.66303724e-01,
#        -3.52965236e-01,  1.80960402e-01, -1.28838018e-01,  1.05369158e-01,
#         2.60821432e-01, -5.41990511e-02,  2.99406409e-01,  1.07950971e-01,
#        -6.25706185e-03, -7.87666813e-02, -1.79174453e-01,  1.29012913e-01,
#        -1.52878553e-01,  7.31766969e-02, -1.63004726e-01,  3.44347954e-01,
#        -1.10212192e-01,  1.80315301e-02,  1.10039905e-01,  1.95966363e-01,
#         3.57571959e-01,  4.25434932e-02,  3.63749743e-01,  1.00759417e-01,
#         1.40031517e-01,  1.06512129e-01,  2.94530153e-01,  2.52679944e-01,
#         1.31020769e-01, -1.79827362e-01,  1.32023752e-01, -7.35308677e-02],
#       dtype=float32)

# %%
X_new[0].shape
# Out:
# (100,)

# %%
## Dependent Features
## Output Features
y = messages[list(map(lambda x: len(x)>0 ,corpus))]
y=pd.get_dummies(y['label'])
y=y.iloc[:,0].values

# %%
y.shape
# Out:
# (5572,)

# %%
X[0].reshape(1,-1).shape
# Out:
# (1, 100)

# %%
## this is the final independent features
import pandas as pd
df=pd.DataFrame()
for i in range(0,len(X)):
    df=df.append(pd.DataFrame(X[i].reshape(1,-1)),ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24460\546578273.py in ?()
#       1 ## this is the final independent features
#       2 import pandas as pd
#       3 df=pd.DataFrame()
#       4 for i in range(0,len(X)):
# ----> 5     df=df.append(pd.DataFrame(X[i].reshape(1,-1)),ignore_index=True)
#
# c:\Users\rkroh\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6317             and name not in self._accessors
#    6318             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319         ):
#    6320             return self[name]
# -> 6321         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'
