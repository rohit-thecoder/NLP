# %%
# !pip install nltk

# %%
corpus = """Hello Welcome, to Rohit's NLP Tuotorials.
Please do watch entire course! to become expert in NLP.
"""

# %%
print(corpus)
# Out:
# Hello Welcome, to Rohit NLP Tuotorials.
# Please do watch entire course! to become expert in NLP.

# %%
#Tokenization
#pagaraph->sentences
from nltk.tokenize import sent_tokenize

# %%
#Tokentization
#pagarapgh->Sentence
from nltk.tokenize import sent_tokenize

# %%
import nltk

# Essential downloads for NLP basics
nltk.download('punkt_tab')    # For sentence tokenization
nltk.download('stopwords')    # For removing common words like 'the', 'is'
nltk.download('wordnet')      # For Lemmatization
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\rkroh\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\rkroh\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\rkroh\AppData\Roaming\nltk_data...
# True

# %%
documents = sent_tokenize(corpus)

# %%
for sentence in documents:
    print(sentence)
# Out:
# Hello Welcome, to Rohit NLP Tuotorials.
# Please do watch entire course!
# to become expert in NLP.

# %%
#Tokenization
#Pagaraph -> words
#sentence -> words
from nltk.tokenize import word_tokenize

# %%
word_tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'to',
#  'Rohit',
#  'NLP',
#  'Tuotorials',
#  '.',
#  'Please',
#  'do',
#  'watch',
#  'entire',
#  'course',
#  '!',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP',
#  '.']

# %%
for sentence in documents:
    print(word_tokenize(sentence))
# Out:
# ['Hello', 'Welcome', ',', 'to', 'Rohit', 'NLP', 'Tuotorials', '.']
# ['Please', 'do', 'watch', 'entire', 'course', '!']
# ['to', 'become', 'expert', 'in', 'NLP', '.']

# %%
from nltk.tokenize import wordpunct_tokenize

# %%
wordpunct_tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'to',
#  'Rohit',
#  "'",
#  's',
#  'NLP',
#  'Tuotorials',
#  '.',
#  'Please',
#  'do',
#  'watch',
#  'entire',
#  'course',
#  '!',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP',
#  '.']

# %%
from nltk.tokenize import TreebankWordTokenizer

# %%
tokenizer = TreebankWordTokenizer()

# %%
tokenizer.tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'to',
#  'Rohit',
#  "'s",
#  'NLP',
#  'Tuotorials.',
#  'Please',
#  'do',
#  'watch',
#  'entire',
#  'course',
#  '!',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP',
#  '.']

# %%
#Steaming
words = ["eating", "eats", "eat", "eaten", "writes", "writing", "write", "programming", "program", "programs", "history"]

# %%
from nltk.stem import PorterStemmer

# %%
stemming = PorterStemmer()
for word in words:
    print(word+"---->"+stemming.stem(word))
# Out:
# eating---->eat
# eats---->eat
# eat---->eat
# eaten---->eaten
# writes---->write
# writing---->write
# write---->write
# programming---->program
# program---->program
# programs---->program
# history---->histori

# %%
stemming.stem("sitting")
# Out:
# 'sit'

# %%
stemming.stem("congratulations")
# Out:
# 'congratul'

# %%
#Regaxp Stemmer
from nltk.stem import RegexpStemmer
reg_stemmer = RegexpStemmer("ing|s$|e$|able$", min=4)
reg_stemmer.stem("eating")
# Out:
# 'eat'

# %%
reg_stemmer.stem("ingeating")
# Out:
# 'eat'

# %%
#Snoball Stemmer
from nltk.stem import SnowballStemmer
snowballstemmer = SnowballStemmer("english")

# %%
for word in words:
    print(word+"--->"+snowballstemmer.stem(word))
# Out:
# eating--->eat
# eats--->eat
# eat--->eat
# eaten--->eaten
# writes--->write
# writing--->write
# write--->write
# programming--->program
# program--->program
# programs--->program
# history--->histori

# %%
stemming.stem("fairly"), stemming.stem("sportingly")
# Out:
# ('fairli', 'sportingli')

# %%
snowballstemmer.stem("fairly"), snowballstemmer.stem("sportingly")
# Out:
# ('fair', 'sport')
